# %% [markdown]
#  *Artificial Intelligence for Vision & NLP* &nbsp; | &nbsp;  *ATU Donegal - Postgrad Diploma in Big Data Analytics & Artificial Intelligence*
#
# # Student Submisison
# Name           : Sebastian Szmytka                <br>
# Student Number : L 00196514        <br>
# Due Date       : 12th May 2359hrs                <br>
# Assignment     : CA2             <br>
# Module         : AI for Vision and NLP    <br>
# Course         : Postgraduate Diploma in Big Data Analytics and AI

# %% [markdown]
# ## NLP and Vision Pipeline : High Level
# An image of your working pipeline at high level can be inserted here

# %% [markdown]
# # Initialisation
# Perform pip installs(or use a requirements.txt) <br>
# perform imports

# %% [markdown]
# ## Install packages

# %%
# pip installs

# %% [markdown]
# ## Imports

# %%
# for jupyter notebook
from IPython.display import IFrame

# imports basics + text and analysis
import os
import spacy
from spacy import displacy
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
import cv2
import pytesseract
from pytesseract import Output
import pymupdf
import sys
import re
print(sys.executable)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import scattertext as sct
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# additional imports for CV
from matplotlib import pyplot as plt
import cv2

# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3

# %%
# test
print("cv2", cv2.__version__)
print("pytesseract", pytesseract.__version__)
# Out:
# cv2 4.13.0
# pytesseract 0.3.13

# %% [markdown]
# # Support Functions

# %% [markdown]
# ### Tools

# %%
def load_files(folder_path, extensions=None):
    """
    Loop to return a list of full file paths from a folder
    """
    files = []
    for root, dirs, filenames in os.walk(folder_path):
        for fname in filenames:
            _, ext = os.path.splitext(fname)
            if extensions is None or ext.lower() in extensions:
                files.append(os.path.join(root, fname))
    
    files = sorted(files)
    print(f"Found {len(files)} files in '{folder_path}'")
    return files
    
def check_fileformat(filepath):
    """
    function to validate file format example if its an image or a pdf file
    1. checks if file exists
    2. identify the extention
    3. make decision based on the file format and process it
    """

    if not os.path.isfile(filepath):
        return f"Error: file not found: {filepath}"

    fileextension = os.path.splitext(filepath)[1].lower()

    print(fileextension)

    try:
        if fileextension == '.pdf':
            print("file type: ", fileextension)
            return pdf_tostring(filepath)
        elif fileextension in [".bmp",".jpg",".png",".tiff",".jpeg"]:
            print("file type: ", fileextension)
            return image_tostring(filepath)
        else:
            print("Unsupported format: ", fileextension)

    except Exception as e:
        return f"An error occurred: {e}"

# %% [markdown]
# ### Functions for NLP

# %%
def npl_pipeline(img_path):

    """
    scikit learn pipeline 

    """
    
    extracted_text = extract_text(img_path, conf_threshold=30) #  changing conf_threshold for poor quality images
    
    # spliting up sentences + cleaning
    sentences_raw = [s.strip() for s in re.split(r'(?<=[.!?])\s+', extracted_text) if len(s.strip()) > 20]
    sentences = [clean_text(s) for s in sentences_raw]
    sentences = [s for s in sentences if len(s) > 20]
    sentences = [stopwords_spacy(s) for s in sentences]
    sentences = [s for s in sentences if len(s) > 20] 

    print(f" >>> Extracted {len(sentences)} chunks from image")

    # for small datasets
    if len(sentences) < 10:
        print(f" Too few sentences — skipping")
        return
    
    # labeling using TF IDF + LDA
    cv = CountVectorizer(stop_words='english', max_features=500, token_pattern=r'\b[a-zA-Z]{3,}\b')
    X_counts = cv.fit_transform(sentences)
                              
    lda = LatentDirichletAllocation(n_components=3, max_iter=20, random_state=42 )

    X_lda = lda.fit_transform(X_counts)
    labels = [f"topic_{np.argmax(row)}" for row in X_lda] 

    # Print top terms
    terms = cv.get_feature_names_out()
    topics = {}
    for i, comp in enumerate(lda.components_):
        top_terms = [terms[j] for j in comp.argsort()[-5:][::-1]]
        topics[f"topic_{i}"] = top_terms
        print(f"topic_{i}: {top_terms}")
    
    print(f"Extracted {len(sentences)} chunks from image")
    
    # train and evaluate
    try:
        X_train, X_test, y_train, y_test = train_test_split(
            sentences, labels,
            test_size=0.3,
            random_state=42)
    except ValueError as e:
        print(f" Train/test split failed: {e}")
        return

    
    pipeline = Pipeline([
        ("tfidf", TfidfVectorizer(
            stop_words='english',
            token_pattern=r'\b[a-zA-Z]{3,}\b'
        )),
        ("clf", LogisticRegression(max_iter=1000, class_weight='balanced'))
    ])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    
    
    # confusion matrix
    label_names = sorted(set(y_test)) 
    cm = confusion_matrix(y_test, y_pred, labels=label_names)
    
    print("\n Confusion Matrix:")
    print(f"{'':>10}", "  ".join(f"{l:>10}" for l in label_names))
    for row_label, row in zip(label_names, cm):
        print(f"{row_label:>10}", "  ".join(f"{v:>10}" for v in row))
    
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred, labels=label_names, cmap='Blues')
    plt.title("NLP Pipeline - Confusion Matrix")
    plt.tight_layout()
    plt.show()

    plt.show()
    
    return {
            "sentences": sentences,
            "labels":    labels,
            "topics":    topics       
        }




def stopwords_spacy(text, verbose=False):
    tokens = word_tokenize(text)
    tokens_clean = [word for word in tokens if word not in sp_stopwords]
    
    if verbose:
        print(f"\n >>> Tokens without stopwords:\n{tokens_clean}")
        print(f"\n >>> Token count: {len(tokens_clean)}")
    
    return ' '.join(tokens_clean)

def clean_text(text):
    # regex generation AI assisted

    # merged words fix 
    text = re.sub(r'([a-z])([A-Z])', r'\1 \2', text) 

    
    #fix common OCR merged words with stopwords glued in
    glued = ['onthe', 'ofthe', 'inthe', 'andthe', 'forthe',
             'oneofmy', 'oneof', 'recipeson', 'handson',
             'thisis', 'wantto', 'grewup', 'sharedt',
             'withme', 'nowitison', 'letme', 'wentto']
    
    for word in glued:
        text = re.sub(rf'\b{word}\b', ' ', text, flags=re.IGNORECASE)
    
    # numbers and letters split
    text = re.sub(r'([a-zA-Z])([\d])', r'\1 \2', text)
    # fix broken OCR 
    text = re.sub(r'(?<=[a-z])\s(?=[a-z]{1,2}\s)', '', text)
    text = text.lower()
    # remove numbers/symbols
    text = re.sub(r'[^a-z\s]', '', text)
    # remove OCR noise tokens
    text = re.sub(r'\b\w{1,2}\b', '', text)         
    # normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip() 

    return text

def extract_text(img_path, conf_threshold=60):
    """
    function with improved Tesseract to deal with bad quality of an image

    """
    img = cv2.imread(img_path)
    d = pytesseract.image_to_data(img, config=r'--oem 3 --psm 6', output_type=Output.DICT)
    words = [d['text'][i] for i in range(len(d['text']))
             if int(d['conf'][i]) > conf_threshold and d['text'][i].strip()]
    return ' '.join(words)

def create_lemmatization(text_to_convert):
    text_to_convert = nlp(text_to_convert)
    for token in text_to_convert:
        print (f"{token.text:{15}} {token.lemma_:{30}}")
    

def create_tokenize(text_token):
    nlp = spacy.load("en_core_web_sm")
    text_token = nlp(text_token)
    for token in text_token:
        print (token.text, token.pos_, end = " | ")

    print("\n\n Number of tokens: ", len(nlp_sentence))



def image_tostring(img):
    """
    image to string function + image to boxes
    """
    print(f"\n image_tostring received: '{img}'")  
    print(f"\n repr: {repr(img)}")                 

    img = cv2.imread(img)
    
    if img is None:
        return f"Error: could not read image"
    
    h, w, c = img.shape
    print(img.shape)

    # draw bounding boxes around detected characters
    boxes = pytesseract.image_to_boxes(img)
    for i in boxes.splitlines():
        i = i.split(' ')
        img = cv2.rectangle(img, (int(i[1]), h - int(i[2])), (int(i[3]), h - int(i[4])), (0, 255, 0), 2) 
        
    plt.imshow(img)
    plt.axis("off")
    plt.show()

    # Convert image to string
    custom_config = r'--oem 3 --psm 6' # changed for better results
    txt = pytesseract.image_to_string(img, config=custom_config)
    print(txt)
    return txt
    
def pdf_tostring(pdf):
    """
    pdf to string function convers pdf to png file
    returns string/text
    """
    doc = pymupdf.open(pdf)
    st = ""
    output_folder = "samples/cv/"
    os.makedirs(output_folder, exist_ok=True)
    # if the pdf has multiple pages this for loop can be edited to accommodate
    for page in doc:
        # setting the dpi to 300 for higher quality image - this can be set higher
        img = page.get_pixmap(dpi=300)
        #Saving the image to local drive where it can be accessed again
        path = os.path.join(output_folder, f"pdf{page.number}.png")
        print("\n Saving to path: ", path)
        print("\n Path type: ", type(path))
        img.save(path)

        print("\n File exists after save: " ,os.path.isfile(path))
        
        txt = image_tostring(path)
        
        #adding txt to one final string
        st += txt
    return st

# %% [markdown]
# ## Functions for Vision

# %% [markdown]
# ### Section 2.1

# %%
def imgaddtext(img, text='TEST', org=(50,50), fontscale=3, color=(0,0,0), thickness=5):
    """
    Function to add text overlay onto an image
    """
    if isinstance(img, str):
       img = cv2.imread(img)
       img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    font = cv2.FONT_HERSHEY_COMPLEX
    cv2.putText(img, text=text, org=org, fontFace=font, fontScale=fontscale, color=color, thickness=thickness)

    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111)
    ax.imshow(img)
    plt.show()
    
def img_process(img):

    """
    function to present section 2.1 Image processing
    """

    print("\n Grayscale using OpenCV \n")
    bwimg = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    print("image resolution: ",bwimg.shape)
    
    print("confirms conversion to NumPy array",type(bwimg))

    plt.imshow(bwimg,cmap="gray")
    plt.show()

  
    # BGR / img is the numpy array, where each pixel contains 3 numbers (B, G, R).
    bgrimg = cv2.imread(img)
    print("\n BGR - three color chanel using OpenCV \n")
    print("to confirm three color chanel: ",bgrimg.shape)
    # This uses Matplotlib to display the image.
    plt.imshow(bgrimg)
    plt.show()

    print("\n COLOR CHANELLS (R + G + B) \n")

    img = cv2.imread(img)
    
    # make a copy of the image
    img_red = img.copy()
    
    # Just show the red channel
    img_red[:, :, 1] = 0    # Zero out contribution from green
    img_red[:, :, 2] = 0    # Zero out contribution from blue
    plt.imshow(img_red)
    plt.show()
    
    img_green = img.copy()
    
    # Just show the red channel
    img_green[:, :, 0] = 0    # Zero out contribution from red
    img_green[:, :, 2] = 0    # Zero out contribution from blue
    plt.imshow(img_green)
    plt.show()
    
    img_blue = img.copy()
    # Just show the blue channel
    img_blue[:, :, 0] = 0    # Zero out contribution from red
    img_blue[:, :, 1] = 0    # Zero out contribution from green
    plt.imshow(img_blue)
    plt.show()

def rgbtobgr1(img):
    """
    function to convert RGB to BGR method 1
    """
    img = cv2.imread(img)

    print("\n Method 1: Using cv2.cvtColor \n")
    # COLOR_BGR2RGB swaps the Blue and Red channels
    imgrgb_method1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(imgrgb_method1)
    plt.axis("off")
    plt.show()

def rgbtobgr2(img):
    """
    function to convert RGB to BGR method 2
    """
    img = cv2.imread(img)
    print("\n Method 2: NumPy array slicing \n")
    # [:,:,::-1] reverses the order of the colour channels
    imgrgb_method2 = img[:,:,::-1]
    plt.imshow(imgrgb_method2)
    plt.axis("off")
    plt.show()

def imgexpand(img,x=2, y=2):

    # Expanding: x - horizontal, y - vertical
    # default to double the size
    
    img = cv2.imread(img)
    res = cv2.resize(img, None,fx=x, fy=y, interpolation = cv2.INTER_CUBIC)
    plt.imshow(res)
    plt.show()

def imgshrink(img,x=0.3, y=0.3):
    
    # Shrinking: x - horizontal, y - vertical
    # default to 0.3 = 30%
    img = cv2.imread(img)
    res = cv2.resize(img, None,fx=x, fy=y, interpolation = cv2.INTER_CUBIC)
    plt.imshow(res)
    plt.show()
    
def imgrotate(img, angle=25, scale=0.5, display=True):
    img = cv2.imread(img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Get image dimensions
    (h, w) = img.shape[:2]
    
    # Define center of rotation
    center = (w // 2, h // 2)
    
    # Generate 2x3 rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, scale)
    
    # Apply affine transformation
    rotated = cv2.warpAffine(img, M, (w, h))
    
    if display:
        plt.imshow(rotated)
        plt.axis("off")
        plt.show()
    
    return rotated


def imagethresholding(img):
    
    img = cv2.imread(img)
    
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Thresholding
    ret,thresh1 = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY)
    ret,thresh2 = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY_INV)
    ret,thresh3 = cv2.threshold(img_gray,127,255,cv2.THRESH_TRUNC)
    ret,thresh4 = cv2.threshold(img_gray,127,255,cv2.THRESH_TOZERO)
    ret,thresh5 = cv2.threshold(img_gray,127,255,cv2.THRESH_TOZERO_INV)
    
    titles = ['Original Image','Binary','Binary INV','TRUNC','TOZERO','TOZERO_INV']
    images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
    
    for i in range(6):
        plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
        plt.title(titles[i])
        plt.xticks([]),plt.yticks([])
    
    plt.show()

def imgblur(img, method='gaussian',blurkrl=(15,15), gauskrl=(9,9)):

    # Blurring from lab example just turned to function

    img = cv2.imread(img)
    imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

   # plt.imshow(imgrgb)
   # plt.title('Original')
   # plt.axis("off")
   # plt.show()

    if method == 'standard':
        result = cv2.blur(imgrgb, blurkrl)
        plt.title('Standard Blur')
    elif method == 'gaussian':
        result = cv2.GaussianBlur(imgrgb, gauskrl, 0)
        plt.title('Gaussian Blur')
    else:
        print("ERROR - use 'standard' or 'gaussian'")
        return

    plt.imshow(result)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Section 2.2

# %%
def imgcontours(img, tx = 127, mode=cv2.RETR_TREE, br=2):
    """
    Function to detect/draw contours on an image
  
    """
    # convert to gray scale
    img_gray = cv2.imread(img, 0)
    
    # load colour version for display
    img_colour = cv2.imread(img)
    img_colour = cv2.cvtColor(img_colour, cv2.COLOR_BGR2RGB)
    
    # apply binary threshold - contours work best on binary images
    ret, thresh = cv2.threshold(img_gray, tx, 255, cv2.THRESH_BINARY)
    
    # find contours
    contours, hierarchy = cv2.findContours(thresh, mode, cv2.CHAIN_APPROX_SIMPLE)
    
    # draw contours on colour image in green
    imgcontour = cv2.drawContours(img_colour.copy(), contours, -1, (0, 255, 0), br)
    
    print(f"\n Number of contours detected: {len(contours)}")
    
    plt.imshow(imgcontour)
    plt.title(f'Contours detected: {len(contours)}')
    plt.axis("off")
    plt.show()

def imgedges(img,x=15, y=15):
    """
    Function to detect edges using Sobel and Laplacian operators
    """
    # load as grayscale - consistent with lab approach
    img = cv2.imread(img, 0)

    sobelx = cv2.Sobel(img, cv2.CV_32F, 1, 0, ksize=x)
    sobely = cv2.Sobel(img, cv2.CV_32F, 0, 1, ksize=y)
    laplacian = cv2.Laplacian(img, cv2.CV_32F)

    fig = plt.figure(figsize=(15, 20))
    ax1 = fig.add_subplot(1, 3, 1)
    plt.title('Sobel X')
    ax1.imshow(sobelx, cmap='gray')
    ax2 = fig.add_subplot(1, 3, 2)
    plt.title('Sobel Y')
    ax2.imshow(sobely, cmap='gray')
    ax3 = fig.add_subplot(1, 3, 3)
    plt.title('Laplacian')
    ax3.imshow(laplacian, cmap='gray')
    plt.show()

# %% [markdown]
# ### Section 2.3

# %%
def imgwatershed(img):
    """
    Function to segment an image using the Watershed algorithm
    """
    img_array = cv2.imread(img)
    imgrgb = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)

    # existing blur function for preprocessing
    img_blur = cv2.medianBlur(imgrgb, 59)
    
    #  grayscale conversion
    gray = cv2.cvtColor(img_blur, cv2.COLOR_BGR2GRAY)

    # threshold approach consistent with imgcontours
    ret, thresh = cv2.threshold(gray, 220, 255, cv2.THRESH_BINARY_INV)

    kernel = np.ones((3,3), np.uint8)
    sure_bg = cv2.dilate(thresh, kernel, iterations=3)
    dist_transform = cv2.distanceTransform(thresh, cv2.DIST_L2, 5)
    ret, sure_fg = cv2.threshold(dist_transform, 0.5*dist_transform.max(), 255, 0)
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    ret, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown==255] = 0
    markers = cv2.watershed(imgrgb, markers)

    # imgcontours logic for drawing results
    contours, hierarchy = cv2.findContours(markers.copy(), cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    for i in range(len(contours)):
        if hierarchy[0][i][3] == -1:
            cv2.drawContours(imgrgb, contours, i, (255,0,0), 2)

    print(f"\n Segments detected: {len(contours)}")
    plt.imshow(imgrgb)
    plt.axis("off")
    plt.show()

def imgcanny(img, blur_krl=(5,5)):
    """
    Function to detect edges using Canny Edge Detection

    """
    img = cv2.imread(img)
    imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # calculate median pixel value for threshold - lab approach
    medianval = np.median(img)
    print(f"\n Median value: {medianval}")

    # apply blur before canny - reduces noise and improves edge detection
    blurred = cv2.blur(imgrgb, ksize=blur_krl)

    # apply canny edge detection
    edges = cv2.Canny(image=blurred, threshold1=medianval, threshold2=255)

    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    axes[0].imshow(imgrgb)
    axes[0].set_title('Original')
    axes[0].axis('off')
    axes[1].imshow(edges, cmap='gray')
    axes[1].set_title(f'Canny Edges - blur kernel {blur_krl}')
    axes[1].axis('off')
    plt.show()

# %% [markdown]
# ### Section 2.4

# %%
def imgenhancment(img, y=21):
    """
    Function for image enhancement
    """
    if y % 2 == 0 or y > 31:
        print(f"Invalid kernel size resetting to 21")
        y = 21

    # load colour and grayscale versions
    img_bgr = cv2.imread(img)
    imgrgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

    # sobel Y edge detection
    sobely = cv2.Sobel(img_gray, cv2.CV_32F, 0, 1, ksize=y)
    sobely = cv2.normalize(np.absolute(sobely), None, 0, 255, cv2.NORM_MINMAX)
    sobely = np.uint8(sobely)

    # binary inverse threshold
    ret, thresh_inv = cv2.threshold(sobely, 127, 255, cv2.THRESH_BINARY_INV)

    # blend to sharpen
    thresh_rgb = cv2.cvtColor(sobely, cv2.COLOR_GRAY2RGB)
    sharpened = cv2.addWeighted(imgrgb, 1.2, thresh_rgb, 0.3, 0)
    sharpened = np.clip(sharpened, 0, 255).astype(np.uint8)

    # display images
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(imgrgb)
    axes[0].set_title('Original')
    axes[0].axis('off')
    axes[1].imshow(sobely, cmap='gray')
    axes[1].set_title('Sobel Y')
    axes[1].axis('off')
    axes[2].imshow(sharpened)
    axes[2].set_title('Sharpened')
    axes[2].axis('off')
    plt.show()

    # histogram comparison
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    color = ('r', 'g', 'b')
    for i, col in enumerate(color):
        ax1.plot(cv2.calcHist([imgrgb], [i], None, [256], [0, 256]), color=col)
        ax2.plot(cv2.calcHist([sharpened], [i], None, [256], [0, 256]), color=col)
    ax1.set_title('Original Histogram')
    ax1.set_xlim([0, 256])
    ax2.set_title('Sharpened Histogram')
    ax2.set_xlim([0, 256])
    plt.show()

# %% [markdown]
# # NLP

# %% [markdown]
# ## Text Extraction end Processing (OCR)

# %%
## code
# test of file format function

cwd = os.getcwd()
print(f"\n Current Directory: {cwd}\n")
file1 = "KaggleDataset/images/0.jp "
file2 = "samples/pdf/Network_3.pdf"

st = check_fileformat(file2)

st_full = st

# just to make it tidier i will limit the amout of text to make the outputs cleaner

st = "\n".join(st.split("\n")[:10])

# print(st)

print(st_full)
# Out:
#  Current Directory: /Users/sebszmytka/GIT_NLP/ca2-assignment-lightarchivist-1
#
# .pdf
# file type:  .pdf
#
#  Saving to path:  samples/cv/pdf0.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/cv/pdf0.png'
#
#  repr: 'samples/cv/pdf0.png'
# (3301, 2551, 3)
# 20116 2nd MABE linfsnoatiional Oonfiansnce on Oomypiitien and Oonotiimniicatiions
# Network! Diaffic Classification Nechniiques and Coniparative Aljalysis
# Machine earning Algorithms
# Shalfig, Xitangzhian Yity AlsiiflAlli Daghianil, (Oo ‘Yao, Niabiin Kicniam Keon, loudill Albldessannia
# Schoo! of Con@jatén Science anid Nechinology,
# Hiaecbin Iiiitifate of Nechinology,
# Harbin 15001 PR), China
# e-nhiaili (jmubanmhadshatiq, yw asiflaghari, Lfjao, Karhisabin, fsudiDdbdessamiall @hit.eda.cn
#
# bstroci—Netwonk Minaftic Olassifibation is a cenfnal fopic fechnique gives @ccurafe resolts jin mefvabrk) traffic
# nowadays in the field off cofayhten scien: If is a weny essénfial  classilfiivation. (Ohis technique is also called Deep Padket
# faski fon infennef service providers (ISPs) fo Know which fypes {inspection (DPI) technique. Bint there fis a problem in this
# of nefwork ayiplicatiions flaw in a oefwork, Network Mbaffic fechnique] The problem is hat iif cannof be used fon
# Olassiffication is the finst stép fo analyze and iddaliffy different = enonypted data network) dpplicationy as numerous network)
# types off applicati¢is Hgyving in a network. Qhinodgh bhis §  aiplications use encrypted fechinigues fo profect data fin
# fechnijie, infennet service providens on oefwonk openafcts can defection. So, this fechniigue Glso filled due fo use off
# oranage the ovehall pertonmence of a network. (Dhene ane many, encrypted fick off applicatiions. (itredifien, the neseanchéts
# Port Based, Pay oad Based an Mixchine Deanning Basel (MIL) fo @asSiffiy inert traf as well as &@ Kiko
# fechnigoe. he most common fechniqoe used these days ts gue ae
# ACh what type off applicatighs fam in the network. Machine
# Machine Deanning (MID) fechnigoe. Which is osed by many, ;
# neseanchers and gof weny effective acconacy, fésilis. In Deaitning Nechnigare Gives weary promising accunicy tésults tf
# paper] we discuss network Sahhic classification fediniques step network! traffic classifiizatich. (his fechiniique is based on
# By) sfep and real fime infennet data sef is develop using — aiiniing and testing dita sets to Classiffyj unkown bolasses)
# network Griffis captone fool, aften that featone extinaction tcl Oénéribuitionn fin this papen, we discuss Netwabrk iralfific
# is use fo extract features from the captite traffi: and then foun —-Classifiitafiidl fechiniques and discuss. Aind then we discuss
# niachine leaning classifiers Support Viecton Machine, coniparative analysis of) foun machine lediiniing blassilficis:
# decision tree, Naive Bays and Bees Net Iaisifizes ane appli) = We Ginsi capture nefwork) traffic osing packef capturing
# Experiniéntal analysis shows fat 04.5 €kissiffiers gives very  applicatigi Wireshark! [15]. Alffen that asin NetMite tod]
# good acogpacy, nesuilf as compare fo offen blassiffiés, we &xtfact fisafones (2)]\) thom the captigte traffltic and thin we
#
# apply foun machine ledrniing Classilfiens fio classify WIWIW,
#
# Kaords-trijjic classifi-ation; machine learning, methoils: DNS] ADP, P2P and Qelinet applications) (The experiniintial
#
# resuli shows thai O4.5 Classilfign give high accuracy as
# 1.  [INDRODUODION compare fo ofhen machine Jearhiing Elassilfigns which ane
# _ j 28.91%.
#
# Network! Qiaiffic (assificatiod fs an imggetant topic (Be rest off the papen fs sihocfors’ as fllows: Saiition fl
# nowadays in fhe field off Compiifen Science. [if is veny, infmodoces fe basi fofbrmafion abiilin
# esseiiial fon linferhiet Senviice Providers (ISPs) 6 manage the a ecfinicquen. aa Glaniihneirafiss
# ovbrall pecibthigies ofa ocivadis (ihaftic classification fs the ar: iasifiiaidh Mined Binallly, ox Gham coliGlision fal
# fils sfep fo identify and classi) onkinown ti¢ivabrk) Ckisses) section {IV!
#
# Network! (Traffic Olassilfibatich plays a very fital role in .
#
# network) security) and management, soch as Iififfusion
#
# Diection, Qualify off Senviice (QoS). (nod this techinigie) M. (NSMWORK (IRARRIO ODASSIBIATION (NAOFINIQUES
# network! operators can take some actions such as fo bllock! Netvabrk (tific Oldesification fis the process to identify
# some flows and manege resounces. They can also find the — (fg network! applications on profocol that exists in a network!
# growth offinetivabrk! dppplicaitichns: [lI]. Netwirk) traffic classifitatich has got great signifiizance
#
# In the Jasi two decades, mumerons netvabrk bralfic in the last two decades. Researchers have proposed many,
# Classilfiatioh fechnigues [| [Al] have been proposed fo — pqgfhsits fo classify] network! applicaticihs: lin this sectigin, we
# classify) unknown Glasses! [he first one jis Port Based — giscuss Puitt-basedl Mechniique, Payjload! Basel Nechnigue and
# Hechiniiqgae. Iii is a greafi fechnliqae fbn network) Machine edtining (IVIL) techniciires:
#
# Classification’ identification. Uhis technique includés 2 port,
#
# which is finstly} nevistered in lnterfist Absign Nombin 4. WoriBavell Technique
#
# Alithority) (AINA) [2]. But this fechniigue filled die fo As we mentioned iin Section | that traditionally, iin this
# increase Of Peen fo Peen applications ()P2P) in [5], which ose fechnique, a blassifiibatidh of! mefwork! fipplications [s
# dynamic por numbers. Dynamic porj momben means  exediited using the well-known ports number. Morediver) we
# onnegistered numiben with linferhist Alssigih Nomiben Alnthionity, ailso discikss&d that first metwork! applications are negiistered fin
# (WANA)! (hen second one fis Paylloatd Based fechniiqae. [ihis
#
# BOR. 1-673 006-20) 7B 9 ON) (Q016 THE PASI
#
# Allitiotized licensed ose lidited tor Atiantio echinoiogical Uhinenslly (AUIU). Dowaloaded on Vinod 09,2026 at 091108 UIC from ISEB Apion. Risstictons arly.
#
#
#  Saving to path:  samples/cv/pdf1.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/cv/pdf1.png'
#
#  repr: 'samples/cv/pdf1.png'
# (3301, 2551, 3)
# thein ports fin the Mnferitf Assigned Nombén Alnthorify expensive hardware fin paftieri seanchiing in a payload, Nhe
# (AINA)! On this way the traiffic fis identilfiéd corfesponding second problem iin this fechinigire fis that if does not wrk inl
# fo the registered pots muntien jtegistened ini AINA! Wible 1 = encrypted network! application trafic. Pinallly, thils approach
# shows different types of! applications and jifs ports numibers needs continuous update off signature patie off mew
# assigned by AINA) Hon instance, B-niail applications use 28  apyplications:
# (SMIDP) port muntiben fo send entails and fo necellve entail 1 10 Wikia
# (POPS) port is used. In this way, web applications use BO u a ions tL usp 89100) a
# nahiber que S on
# eal data set (Labelled Dafa Sef) . fn this technique, a machine
# — learning olassilfiien is as input and then using the
# Fee ee eT ee ELSIE Soe WELD trained sone freficion, onkincxsn Glasses are Sis
# (heirs ans areas iin o@aéhine learning fechiniicq)
# cope eel ar] unsiperst fd lenming fake
# Maofuine Deamitg (Nf) Mecfnigae
# ! — |
# a
# ee a) eee]
# _Svewied [| Cisne
# Giga. i oan eng
# pt) gee Deoing Dente
# Sopeniscd learfing taofinigos is a maifiios [eeening
# technique {)I). (his technique is also called Classilficatiion
# (his; this £é¢hnique does riot provide good Elzsification nhethods) Mhis tézhiniique needs a contplete labeled data set fo
# accuracy) resiidts [6], [2]. Morediver) this technique fails due classify] Glasses. Below ane thie two figanes whiich
# fo using dynaniic port numbien off new Applications to evatle are (sco Ho esiils Wo 10). een tied the aopeawacctl
# being sef and then if will produce pirdiction output iin new data
# B. Payload-Based Technique saniples;
# Uhiis method is also called Deep Packet Inspection
# technique (DPI). In this technique, the contents of) the 1.  BSoown Dita
# packets ane examined looking chiaracteristics signafunes of] cs
# the network! applications iin the traffit) Mhis is the First _”
# allferfiative fo porits-Dased method. (This technique iis specially, nown Response)
# proposed fon Peen fo Peen (P2P) applications. If means
# applicatidhs whlch use dynamic por numbén fo idgntifiy a
# traffi if! @ network. Below iis the fable, which Mlustrates = ~——__,
# exaniples, used by, Kiardsiannis €t al) tin [5l]) _
# (HAIBILE fil. KISREVGIAINSES DESCRIBE SMRINGS AL DAB BEGINNING (New Dita
# PRIOMOOOD PAYIDOAID igure 2. Mietiod diéoriptiion by nathwctifks
# "
# Mihis method infizrs function from labeled training Gita set
# a
# Piast TS >
# | oe 1) = yy, KATA ere on he DIE
# Sa i es est i a
# Press |G as | CUP SS fits fipa predicted wali,
# a
# Uinstipervised fechiniciite fis also called a clusten technique.
# In this method) thene is no need of complete labeled data sets)
# Bilt iin this té¢hinique, we stumble opon some problems:  Uiisupenvised fis a type off machine leaning. (hits the tésulf
# (he first probléin iin this technique jis thai if needs a veny
# Allifiofized licensed ose [inited for Attantic Rectinological Uhimenstiy, (ALU). Dobreted on Uanot 08,2076 at ONG05 OIG trom IEE ee. Risifictions agpiy.
#
#
#  Saving to path:  samples/cv/pdf2.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/cv/pdf2.png'
#
#  repr: 'samples/cv/pdf2.png'
# (3301, 2551, 3)
# outpot of} machine ledrniing fraiining does not identify on D. Implementation of Machine Dearing Algorithms
# nmichine learhing algorithm on on iinsfarides)
# Ol. = INSDWORK DRABEIO OOASSIFICATION MODDED Fon ia ving) 8 fel, OnE ised] andl semi
# In this section! we explain the nefwork traffic gqpenvised learhing Algoriffiin. Fon implenigntation off
# Classifiitation stracturé model, which inclodes sfep by step nace learning algorithm, there ane many, idols available
# prowess as shown iin Big. 3. (his step by sfep process method — op jinfétnet, bot most cdrmonly nowadays are used Matab
# willl show you how fo use oetvzrk! Classification — (14) and Wikkal blasSifficatiion simulation fools (IG). lin this
# technique to identify 2 classify) unknown netvabrh) Gafic = papen, we ose Wika fool and appily) fon madhine learning,
# classes using michiiie lledrhing techinigiie: algoritfiin O4.5, Supporf Vecton Machine} BiayesNet and
# NéiveBayes fo bitild classification model using 10 Holden
# AL Result And Obsdrvation
# ft gets tandem neo: fs sg
# Features Extraction Selection the siritlation fool gives défailled results about the applied
# Step# 2 algoriffiins such as accuracy, défallled linfbmiation, training
# time dihd néball etic. [in this work! we ose folim classilfiiens 04.5,
# Support Vector Machine) BayesNef anid NaiiveBayes. Bilt
# _ C#5 algorithm gives weary high resol agponaoy, as compare tio
# von shea ew a
# resullis and figord 4 shown the comparison of) accunacy,
# fis sin in: sin
# WAIBILE Ml, AICOMRIAIOY) RIBSOIDN ANID OONPAIRTISON OF MILA!
# a
# ia
# es
# A. Weiiork Traffic Cgptune
# OS is tis isd al nes igen sep, efi inches
# Gaia collection. fn this sfc, tie real tithe nea traffic ts In the (Bie WM i is clean that CALS machine ledthing
# captioned. if is alsé Known as data collection step. Uhene ane
# i — ao Classifiars gives aocuracy resulf betfian than ofhen applied
# many) fco)s fon network! naif captioning, bot Nopdamp ido)
# can be used fo capture the real time netviirk brdfific. Do  Sutchline leaning Elassifiés and also Bilg. 4 shows this
# m2 accuracy mesuli as well as big. §. Shows the fecal anid
# packiet capturing and analyzing. Wie cajpttited the traffic the
# NIG DIP precision coniparigon nesllt im which G45 ¢lassilfiens result is
# duration off one minoté off WIWIW, HOP, anid
# (eliét application very, good as conmpare fo othen MID blassilfiths:
# B. Feature Extraction Selection
# Alffen capfore network! trafiiib data, the fisafane selection
# and extraction step follow. In this sfep, the fiafunes ane
# exiinacted fiom the capfuned data such as packet dimaticny Se
# packet Jength; jinfen dirrival packet titne profocol efc. Then
# extracted fkafunes are osed fo trail the machine Iedrhing Ogicooracy
# classiffién. Hon fkafare extraction, Perl script can be used) fo Rod
# exitact the fzafore Féin captured data se) Bot we use = | g oan
# Netiniiife fool (20 fon fafa exiiraction and we @xtraci 23
# fiationes) Wie use IMIS Excel fbn sawing the dataset fii Wek
# fool as a Comma Seygrafed Values (OSV) Qike tachi oa.s SYM = Bayes Net Milive Base
# C1 hainierg Process Sampling,
# [in this stage, dafa sets are sampled fin supenvised) bare Bh boagany ec and coe
# learhing, technique. In supenvised learning, data are finsi
# labéled fo classify onkinown network! applications:
# Allifiofized licensed ase limited for Alfantic Mectinolagical Qiivenstiy, (AIO). Dobrbeted on Uanof 08,2076 at OSN1G05 OIG trom IEE ere. Restrictions axgply.
#
#
#  Saving to path:  samples/cv/pdf3.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/cv/pdf3.png'
#
#  repr: 'samples/cv/pdf3.png'
# (3301, 2551, 3)
# Neétvzbrk (Tiafific Olassilfiization Dechniques (Pai Biased, Pay,
#
# 100.0% oad Based and Mitchiine Uearning Based technique) and
#
# 6 004 thein limitation. Then we stnactane modeé] of) netwibrk thaffic
# 3 ons classification fhom trafiis capture fo end nésullo
#
# & mos hon comparative adalysis off foun algonithms, we captone
# 2 some Gieral fivd WWW, DNS] ADP, PSP and THUNB applications
# = wu Wfiecsion | (Walia duratich off 1 mimufe using Wine Shark fool and
#
# © s0.00% a , = 7
#
# © oom extract 23 feafunes using Netnimite fool. Alfien tat, traffic iis
#
# re Classified usiti foun machine learning algonithris
#
# one Bxperinizntal nesulli shiow thi 04.8 decision allgonithin gives
# oan am Boge en SE Basa high accuracy, resulli as compare fo offen Supporti Vietton
# Machine, BiyesNef and NaiveBiaes rhachiine ledtining
# Clasbilfiens
# RIGORE 6. RIEOADD GND PREDISION OF FOUR MADEN DESRNING
# OnASSIRIBRS IREEERENOBS
# (0) Qhoy nfimodoctio# fo  (Nefwork) Qlassificatiion,
#
# Higare 6 and (7 shows the ré&vall and pretision result of! hittpy//vwwrwcoisco.comi/cren (is td/idors Aisi 7../Achiap05 pid
# captured WIWIW] DNS] EMP) PSP and HDNIET applications: fotienni&t _Nomhiiers (IANA)
# From which fit fs clean that which dpplication recall and ouifize oD Cee 12
# it {8 clean thal INS and WWM) fppfidation Fecal and = Sl © eure, andl C. Rmiae, 5 Soreey) ob i echiignes fin tater
#
# OkSificatidh using Machine Deathing, (HEE Surveys and
#
# precisidi resuli fis weny) poon as compare fo then Tiliicials, NOG), pp. 56-76, ZOU)
# applications: [A] Pawel Boreni§G] On Oiffarent says to classify Doninie0 raf a afin
# review Of selected publlicatiions Theoretical nd Ajyplied Inftnniiatiios)
#
# 1.2 20m)
#
# 1 (Oo) ©. Raragianniies) Al Bnoildo, ai M. Balonfsos, “Dnanspdii bayen
# : O04.5 ideiifification of P2P plificl? Poo. of ACM SIGCOMM IMI)
#
# og Ali@ast) 2002).
#
# oe BsvM | (6) 1. Raragiannies, AL Broidio, N. Browniéa, KL Olafliy andl ML Haken
#
# = "Bille-shidting, in the infethety a chikiicterization off p2p tnillfic in the
#
# oa Odayes Backbone”) Proc. o1AGM SIGCOMIM INI] Aligust) 2004).
#
# e Geo (2) Al Moore and Kl Papagilan ik] Mowerd the accuiats ideiiGiliicatiion
#
# Oi Nleive of network! apphicatiions?* fin Pons. OHPAM (ibnf), Mirch, 2005)
# , Bayes [8] boy 0.0. Ngoyen anid Giteriville Alnniifage. “Al Sanvey) off Dechniiqaes
# = os ame eel fn Interhet Uitatic Olessilficatidi asin’) Machine Dedtning” IBBB
# Oonithonications ra Mol. 10, No. 4, pp.
# Figure 6. KizGall off fon machine ledrining Glassilfiers on tive apyplicaiticiajs: Fon Owe anne " me
# (9) Alton QaWado, Carlos Kanfifenskil, O8za Szabd, Balaizs Pétien Gexifivy
# (ndith KEIneiiSténio Berhindes afi Djfinel Sadok. “A) Sonvey on
# 12 Intent Ideiifitation{? (HHA Oometimidations Survey
# § toi, Wo. 1, 8.3, pp. 7-52, sk (iin TH
# ef | re ff) | os [10] fan Bl. Wien afd Bibs Brafik, Data Vining: Piactical Machin
# ox Deathing (Mools and Mechnigues, 2th edition) Morgan Klacifiiaon
# es) fn) 8) ic edt, Sen Eon
# erm) UE) UP) A ae a et a eee
# oa on
# SA | oe ee
# UE SU Ys | atic cesncieetenta emt
# ee NO) Skin Emkcomens in Komen Cat CFE)
# Aigore 7. Precision off bon machine leanniing Ghassiifiens of five (12 kil (hake Wie.
# epifioaticihe: bttpZ/ixeoworathworks.com/downlodils/
# IV. CONODUSION D6] Mo capfon atitine Foal] Wea efdck! fol) lesan ftp
# mnrmcwrinestieerk) ong.
#
# In thiis papen, we discuss Netvabrki traffic classiffiization ig] Kuldeep Sing, Sonil Agrawal, “Compimatiive Aljalyssis off Alive
# techniques and discuss How new feseanchens on new Machin Dedthiog Algonithins fon 0 Mitailfic Olassilfication” 1H
# network) operators will apply the netvork| | foterfiational Oonfrence on 2011 Emerging Ooends in Network and
# Classifiitatiion téc¢hniique using mdithiine leaning algorithm fo Oongfiiien Corichonicatikin
# classify) unknown applications and manage perfonmance off — !!I — Borie, in Tyan peters Manas Bo bere
# network. Aind thien we pectin contparative atalypis off fisun Research — INPE] SP) Bazil)
# machine Jeamiing (lassilfilens) Hirstly} we denionstrate
# RifFingized llconsld ose ited to: Btantic Tenfinological Ulisensily (AITO). OoSebeded on SiaroA 0,206 at EOE CATO inom IEE Poe Aibsifictions agply.
#
#
#  Saving to path:  samples/cv/pdf4.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/cv/pdf4.png'
#
#  repr: 'samples/cv/pdf4.png'
# (3301, 2551, 3)
# (U8) tan A. Mitten and Bibe Brank, Data Miinings Piactical Machine [20] Intmodoction to  NetMafe fol!) download  infbrination
# Deaniing Mools anid Mechniiqaes, edition) Miongan Kanfirignn hittpsd//dan acoktt.ca/niiny/ calcolating-fiiwr-Sigtiistiios-usiing-
# Piibfishiens, Sah Brancisoo, OAl, 2005) neiniate/conmint=page3 00
#
# (09) Gie Oheng, Ritssell Greiner) “Dearing Bayesian Belief) Network  {2Il] Oao, lie, ef al. “Network [tific Olassilfication Using Reatone
# Qassifies: Algonitiiqns and System," Deparfinent off Conipoting Selection and a Optiniization.” Gouirial off)
# Science, Unhviensity of Allberizd Edinonton, Allbeiita, Oanadéo Oonirhonicatiions 10.00 (200
#
# ABiofced loendd ase Omited tai Aandi DecGoologioal (iisersiy (NO, Oo Zabshes on Mino 08,20 a OOS OO feo IBGE Bc, Restrictions agiply.
#
# 20116 2nd MABE linfsnoatiional Oonfiansnce on Oomypiitien and Oonotiimniicatiions
# Network! Diaffic Classification Nechniiques and Coniparative Aljalysis
# Machine earning Algorithms
# Shalfig, Xitangzhian Yity AlsiiflAlli Daghianil, (Oo ‘Yao, Niabiin Kicniam Keon, loudill Albldessannia
# Schoo! of Con@jatén Science anid Nechinology,
# Hiaecbin Iiiitifate of Nechinology,
# Harbin 15001 PR), China
# e-nhiaili (jmubanmhadshatiq, yw asiflaghari, Lfjao, Karhisabin, fsudiDdbdessamiall @hit.eda.cn
#
# bstroci—Netwonk Minaftic Olassifibation is a cenfnal fopic fechnique gives @ccurafe resolts jin mefvabrk) traffic
# nowadays in the field off cofayhten scien: If is a weny essénfial  classilfiivation. (Ohis technique is also called Deep Padket
# faski fon infennef service providers (ISPs) fo Know which fypes {inspection (DPI) technique. Bint there fis a problem in this
# of nefwork ayiplicatiions flaw in a oefwork, Network Mbaffic fechnique] The problem is hat iif cannof be used fon
# Olassiffication is the finst stép fo analyze and iddaliffy different = enonypted data network) dpplicationy as numerous network)
# types off applicati¢is Hgyving in a network. Qhinodgh bhis §  aiplications use encrypted fechinigues fo profect data fin
# fechnijie, infennet service providens on oefwonk openafcts can defection. So, this fechniigue Glso filled due fo use off
# oranage the ovehall pertonmence of a network. (Dhene ane many, encrypted fick off applicatiions. (itredifien, the neseanchéts
# Port Based, Pay oad Based an Mixchine Deanning Basel (MIL) fo @asSiffiy inert traf as well as &@ Kiko
# fechnigoe. he most common fechniqoe used these days ts gue ae
# ACh what type off applicatighs fam in the network. Machine
# Machine Deanning (MID) fechnigoe. Which is osed by many, ;
# neseanchers and gof weny effective acconacy, fésilis. In Deaitning Nechnigare Gives weary promising accunicy tésults tf
# paper] we discuss network Sahhic classification fediniques step network! traffic classifiizatich. (his fechiniique is based on
# By) sfep and real fime infennet data sef is develop using — aiiniing and testing dita sets to Classiffyj unkown bolasses)
# network Griffis captone fool, aften that featone extinaction tcl Oénéribuitionn fin this papen, we discuss Netwabrk iralfific
# is use fo extract features from the captite traffi: and then foun —-Classifiitafiidl fechiniques and discuss. Aind then we discuss
# niachine leaning classifiers Support Viecton Machine, coniparative analysis of) foun machine lediiniing blassilficis:
# decision tree, Naive Bays and Bees Net Iaisifizes ane appli) = We Ginsi capture nefwork) traffic osing packef capturing
# Experiniéntal analysis shows fat 04.5 €kissiffiers gives very  applicatigi Wireshark! [15]. Alffen that asin NetMite tod]
# good acogpacy, nesuilf as compare fo offen blassiffiés, we &xtfact fisafones (2)]\) thom the captigte traffltic and thin we
#
# apply foun machine ledrniing Classilfiens fio classify WIWIW,
#
# Kaords-trijjic classifi-ation; machine learning, methoils: DNS] ADP, P2P and Qelinet applications) (The experiniintial
#
# resuli shows thai O4.5 Classilfign give high accuracy as
# 1.  [INDRODUODION compare fo ofhen machine Jearhiing Elassilfigns which ane
# _ j 28.91%.
#
# Network! Qiaiffic (assificatiod fs an imggetant topic (Be rest off the papen fs sihocfors’ as fllows: Saiition fl
# nowadays in fhe field off Compiifen Science. [if is veny, infmodoces fe basi fofbrmafion abiilin
# esseiiial fon linferhiet Senviice Providers (ISPs) 6 manage the a ecfinicquen. aa Glaniihneirafiss
# ovbrall pecibthigies ofa ocivadis (ihaftic classification fs the ar: iasifiiaidh Mined Binallly, ox Gham coliGlision fal
# fils sfep fo identify and classi) onkinown ti¢ivabrk) Ckisses) section {IV!
#
# Network! (Traffic Olassilfibatich plays a very fital role in .
#
# network) security) and management, soch as Iififfusion
#
# Diection, Qualify off Senviice (QoS). (nod this techinigie) M. (NSMWORK (IRARRIO ODASSIBIATION (NAOFINIQUES
# network! operators can take some actions such as fo bllock! Netvabrk (tific Oldesification fis the process to identify
# some flows and manege resounces. They can also find the — (fg network! applications on profocol that exists in a network!
# growth offinetivabrk! dppplicaitichns: [lI]. Netwirk) traffic classifitatich has got great signifiizance
#
# In the Jasi two decades, mumerons netvabrk bralfic in the last two decades. Researchers have proposed many,
# Classilfiatioh fechnigues [| [Al] have been proposed fo — pqgfhsits fo classify] network! applicaticihs: lin this sectigin, we
# classify) unknown Glasses! [he first one jis Port Based — giscuss Puitt-basedl Mechniique, Payjload! Basel Nechnigue and
# Hechiniiqgae. Iii is a greafi fechnliqae fbn network) Machine edtining (IVIL) techniciires:
#
# Classification’ identification. Uhis technique includés 2 port,
#
# which is finstly} nevistered in lnterfist Absign Nombin 4. WoriBavell Technique
#
# Alithority) (AINA) [2]. But this fechniigue filled die fo As we mentioned iin Section | that traditionally, iin this
# increase Of Peen fo Peen applications ()P2P) in [5], which ose fechnique, a blassifiibatidh of! mefwork! fipplications [s
# dynamic por numbers. Dynamic porj momben means  exediited using the well-known ports number. Morediver) we
# onnegistered numiben with linferhist Alssigih Nomiben Alnthionity, ailso discikss&d that first metwork! applications are negiistered fin
# (WANA)! (hen second one fis Paylloatd Based fechniiqae. [ihis
#
# BOR. 1-673 006-20) 7B 9 ON) (Q016 THE PASI
#
# Allitiotized licensed ose lidited tor Atiantio echinoiogical Uhinenslly (AUIU). Dowaloaded on Vinod 09,2026 at 091108 UIC from ISEB Apion. Risstictons arly.
# thein ports fin the Mnferitf Assigned Nombén Alnthorify expensive hardware fin paftieri seanchiing in a payload, Nhe
# (AINA)! On this way the traiffic fis identilfiéd corfesponding second problem iin this fechinigire fis that if does not wrk inl
# fo the registered pots muntien jtegistened ini AINA! Wible 1 = encrypted network! application trafic. Pinallly, thils approach
# shows different types of! applications and jifs ports numibers needs continuous update off signature patie off mew
# assigned by AINA) Hon instance, B-niail applications use 28  apyplications:
# (SMIDP) port muntiben fo send entails and fo necellve entail 1 10 Wikia
# (POPS) port is used. In this way, web applications use BO u a ions tL usp 89100) a
# nahiber que S on
# eal data set (Labelled Dafa Sef) . fn this technique, a machine
# — learning olassilfiien is as input and then using the
# Fee ee eT ee ELSIE Soe WELD trained sone freficion, onkincxsn Glasses are Sis
# (heirs ans areas iin o@aéhine learning fechiniicq)
# cope eel ar] unsiperst fd lenming fake
# Maofuine Deamitg (Nf) Mecfnigae
# ! — |
# a
# ee a) eee]
# _Svewied [| Cisne
# Giga. i oan eng
# pt) gee Deoing Dente
# Sopeniscd learfing taofinigos is a maifiios [eeening
# technique {)I). (his technique is also called Classilficatiion
# (his; this £é¢hnique does riot provide good Elzsification nhethods) Mhis tézhiniique needs a contplete labeled data set fo
# accuracy) resiidts [6], [2]. Morediver) this technique fails due classify] Glasses. Below ane thie two figanes whiich
# fo using dynaniic port numbien off new Applications to evatle are (sco Ho esiils Wo 10). een tied the aopeawacctl
# being sef and then if will produce pirdiction output iin new data
# B. Payload-Based Technique saniples;
# Uhiis method is also called Deep Packet Inspection
# technique (DPI). In this technique, the contents of) the 1.  BSoown Dita
# packets ane examined looking chiaracteristics signafunes of] cs
# the network! applications iin the traffit) Mhis is the First _”
# allferfiative fo porits-Dased method. (This technique iis specially, nown Response)
# proposed fon Peen fo Peen (P2P) applications. If means
# applicatidhs whlch use dynamic por numbén fo idgntifiy a
# traffi if! @ network. Below iis the fable, which Mlustrates = ~——__,
# exaniples, used by, Kiardsiannis €t al) tin [5l]) _
# (HAIBILE fil. KISREVGIAINSES DESCRIBE SMRINGS AL DAB BEGINNING (New Dita
# PRIOMOOOD PAYIDOAID igure 2. Mietiod diéoriptiion by nathwctifks
# "
# Mihis method infizrs function from labeled training Gita set
# a
# Piast TS >
# | oe 1) = yy, KATA ere on he DIE
# Sa i es est i a
# Press |G as | CUP SS fits fipa predicted wali,
# a
# Uinstipervised fechiniciite fis also called a clusten technique.
# In this method) thene is no need of complete labeled data sets)
# Bilt iin this té¢hinique, we stumble opon some problems:  Uiisupenvised fis a type off machine leaning. (hits the tésulf
# (he first probléin iin this technique jis thai if needs a veny
# Allifiofized licensed ose [inited for Attantic Rectinological Uhimenstiy, (ALU). Dobreted on Uanot 08,2076 at ONG05 OIG trom IEE ee. Risifictions agpiy.
# outpot of} machine ledrniing fraiining does not identify on D. Implementation of Machine Dearing Algorithms
# nmichine learhing algorithm on on iinsfarides)
# Ol. = INSDWORK DRABEIO OOASSIFICATION MODDED Fon ia ving) 8 fel, OnE ised] andl semi
# In this section! we explain the nefwork traffic gqpenvised learhing Algoriffiin. Fon implenigntation off
# Classifiitation stracturé model, which inclodes sfep by step nace learning algorithm, there ane many, idols available
# prowess as shown iin Big. 3. (his step by sfep process method — op jinfétnet, bot most cdrmonly nowadays are used Matab
# willl show you how fo use oetvzrk! Classification — (14) and Wikkal blasSifficatiion simulation fools (IG). lin this
# technique to identify 2 classify) unknown netvabrh) Gafic = papen, we ose Wika fool and appily) fon madhine learning,
# classes using michiiie lledrhing techinigiie: algoritfiin O4.5, Supporf Vecton Machine} BiayesNet and
# NéiveBayes fo bitild classification model using 10 Holden
# AL Result And Obsdrvation
# ft gets tandem neo: fs sg
# Features Extraction Selection the siritlation fool gives défailled results about the applied
# Step# 2 algoriffiins such as accuracy, défallled linfbmiation, training
# time dihd néball etic. [in this work! we ose folim classilfiiens 04.5,
# Support Vector Machine) BayesNef anid NaiiveBayes. Bilt
# _ C#5 algorithm gives weary high resol agponaoy, as compare tio
# von shea ew a
# resullis and figord 4 shown the comparison of) accunacy,
# fis sin in: sin
# WAIBILE Ml, AICOMRIAIOY) RIBSOIDN ANID OONPAIRTISON OF MILA!
# a
# ia
# es
# A. Weiiork Traffic Cgptune
# OS is tis isd al nes igen sep, efi inches
# Gaia collection. fn this sfc, tie real tithe nea traffic ts In the (Bie WM i is clean that CALS machine ledthing
# captioned. if is alsé Known as data collection step. Uhene ane
# i — ao Classifiars gives aocuracy resulf betfian than ofhen applied
# many) fco)s fon network! naif captioning, bot Nopdamp ido)
# can be used fo capture the real time netviirk brdfific. Do  Sutchline leaning Elassifiés and also Bilg. 4 shows this
# m2 accuracy mesuli as well as big. §. Shows the fecal anid
# packiet capturing and analyzing. Wie cajpttited the traffic the
# NIG DIP precision coniparigon nesllt im which G45 ¢lassilfiens result is
# duration off one minoté off WIWIW, HOP, anid
# (eliét application very, good as conmpare fo othen MID blassilfiths:
# B. Feature Extraction Selection
# Alffen capfore network! trafiiib data, the fisafane selection
# and extraction step follow. In this sfep, the fiafunes ane
# exiinacted fiom the capfuned data such as packet dimaticny Se
# packet Jength; jinfen dirrival packet titne profocol efc. Then
# extracted fkafunes are osed fo trail the machine Iedrhing Ogicooracy
# classiffién. Hon fkafare extraction, Perl script can be used) fo Rod
# exitact the fzafore Féin captured data se) Bot we use = | g oan
# Netiniiife fool (20 fon fafa exiiraction and we @xtraci 23
# fiationes) Wie use IMIS Excel fbn sawing the dataset fii Wek
# fool as a Comma Seygrafed Values (OSV) Qike tachi oa.s SYM = Bayes Net Milive Base
# C1 hainierg Process Sampling,
# [in this stage, dafa sets are sampled fin supenvised) bare Bh boagany ec and coe
# learhing, technique. In supenvised learning, data are finsi
# labéled fo classify onkinown network! applications:
# Allifiofized licensed ase limited for Alfantic Mectinolagical Qiivenstiy, (AIO). Dobrbeted on Uanof 08,2076 at OSN1G05 OIG trom IEE ere. Restrictions axgply.
# Neétvzbrk (Tiafific Olassilfiization Dechniques (Pai Biased, Pay,
#
# 100.0% oad Based and Mitchiine Uearning Based technique) and
#
# 6 004 thein limitation. Then we stnactane modeé] of) netwibrk thaffic
# 3 ons classification fhom trafiis capture fo end nésullo
#
# & mos hon comparative adalysis off foun algonithms, we captone
# 2 some Gieral fivd WWW, DNS] ADP, PSP and THUNB applications
# = wu Wfiecsion | (Walia duratich off 1 mimufe using Wine Shark fool and
#
# © s0.00% a , = 7
#
# © oom extract 23 feafunes using Netnimite fool. Alfien tat, traffic iis
#
# re Classified usiti foun machine learning algonithris
#
# one Bxperinizntal nesulli shiow thi 04.8 decision allgonithin gives
# oan am Boge en SE Basa high accuracy, resulli as compare fo offen Supporti Vietton
# Machine, BiyesNef and NaiveBiaes rhachiine ledtining
# Clasbilfiens
# RIGORE 6. RIEOADD GND PREDISION OF FOUR MADEN DESRNING
# OnASSIRIBRS IREEERENOBS
# (0) Qhoy nfimodoctio# fo  (Nefwork) Qlassificatiion,
#
# Higare 6 and (7 shows the ré&vall and pretision result of! hittpy//vwwrwcoisco.comi/cren (is td/idors Aisi 7../Achiap05 pid
# captured WIWIW] DNS] EMP) PSP and HDNIET applications: fotienni&t _Nomhiiers (IANA)
# From which fit fs clean that which dpplication recall and ouifize oD Cee 12
# it {8 clean thal INS and WWM) fppfidation Fecal and = Sl © eure, andl C. Rmiae, 5 Soreey) ob i echiignes fin tater
#
# OkSificatidh using Machine Deathing, (HEE Surveys and
#
# precisidi resuli fis weny) poon as compare fo then Tiliicials, NOG), pp. 56-76, ZOU)
# applications: [A] Pawel Boreni§G] On Oiffarent says to classify Doninie0 raf a afin
# review Of selected publlicatiions Theoretical nd Ajyplied Inftnniiatiios)
#
# 1.2 20m)
#
# 1 (Oo) ©. Raragianniies) Al Bnoildo, ai M. Balonfsos, “Dnanspdii bayen
# : O04.5 ideiifification of P2P plificl? Poo. of ACM SIGCOMM IMI)
#
# og Ali@ast) 2002).
#
# oe BsvM | (6) 1. Raragiannies, AL Broidio, N. Browniéa, KL Olafliy andl ML Haken
#
# = "Bille-shidting, in the infethety a chikiicterization off p2p tnillfic in the
#
# oa Odayes Backbone”) Proc. o1AGM SIGCOMIM INI] Aligust) 2004).
#
# e Geo (2) Al Moore and Kl Papagilan ik] Mowerd the accuiats ideiiGiliicatiion
#
# Oi Nleive of network! apphicatiions?* fin Pons. OHPAM (ibnf), Mirch, 2005)
# , Bayes [8] boy 0.0. Ngoyen anid Giteriville Alnniifage. “Al Sanvey) off Dechniiqaes
# = os ame eel fn Interhet Uitatic Olessilficatidi asin’) Machine Dedtning” IBBB
# Oonithonications ra Mol. 10, No. 4, pp.
# Figure 6. KizGall off fon machine ledrining Glassilfiers on tive apyplicaiticiajs: Fon Owe anne " me
# (9) Alton QaWado, Carlos Kanfifenskil, O8za Szabd, Balaizs Pétien Gexifivy
# (ndith KEIneiiSténio Berhindes afi Djfinel Sadok. “A) Sonvey on
# 12 Intent Ideiifitation{? (HHA Oometimidations Survey
# § toi, Wo. 1, 8.3, pp. 7-52, sk (iin TH
# ef | re ff) | os [10] fan Bl. Wien afd Bibs Brafik, Data Vining: Piactical Machin
# ox Deathing (Mools and Mechnigues, 2th edition) Morgan Klacifiiaon
# es) fn) 8) ic edt, Sen Eon
# erm) UE) UP) A ae a et a eee
# oa on
# SA | oe ee
# UE SU Ys | atic cesncieetenta emt
# ee NO) Skin Emkcomens in Komen Cat CFE)
# Aigore 7. Precision off bon machine leanniing Ghassiifiens of five (12 kil (hake Wie.
# epifioaticihe: bttpZ/ixeoworathworks.com/downlodils/
# IV. CONODUSION D6] Mo capfon atitine Foal] Wea efdck! fol) lesan ftp
# mnrmcwrinestieerk) ong.
#
# In thiis papen, we discuss Netvabrki traffic classiffiization ig] Kuldeep Sing, Sonil Agrawal, “Compimatiive Aljalyssis off Alive
# techniques and discuss How new feseanchens on new Machin Dedthiog Algonithins fon 0 Mitailfic Olassilfication” 1H
# network) operators will apply the netvork| | foterfiational Oonfrence on 2011 Emerging Ooends in Network and
# Classifiitatiion téc¢hniique using mdithiine leaning algorithm fo Oongfiiien Corichonicatikin
# classify) unknown applications and manage perfonmance off — !!I — Borie, in Tyan peters Manas Bo bere
# network. Aind thien we pectin contparative atalypis off fisun Research — INPE] SP) Bazil)
# machine Jeamiing (lassilfilens) Hirstly} we denionstrate
# RifFingized llconsld ose ited to: Btantic Tenfinological Ulisensily (AITO). OoSebeded on SiaroA 0,206 at EOE CATO inom IEE Poe Aibsifictions agply.
# (U8) tan A. Mitten and Bibe Brank, Data Miinings Piactical Machine [20] Intmodoction to  NetMafe fol!) download  infbrination
# Deaniing Mools anid Mechniiqaes, edition) Miongan Kanfirignn hittpsd//dan acoktt.ca/niiny/ calcolating-fiiwr-Sigtiistiios-usiing-
# Piibfishiens, Sah Brancisoo, OAl, 2005) neiniate/conmint=page3 00
#
# (09) Gie Oheng, Ritssell Greiner) “Dearing Bayesian Belief) Network  {2Il] Oao, lie, ef al. “Network [tific Olassilfication Using Reatone
# Qassifies: Algonitiiqns and System," Deparfinent off Conipoting Selection and a Optiniization.” Gouirial off)
# Science, Unhviensity of Allberizd Edinonton, Allbeiita, Oanadéo Oonirhonicatiions 10.00 (200
#
# ABiofced loendd ase Omited tai Aandi DecGoologioal (iisersiy (NO, Oo Zabshes on Mino 08,20 a OOS OO feo IBGE Bc, Restrictions agiply.

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# ### Tokenisation
# segmenting sentences in to units called "tokens"

# %%
# tokenisation - load english language library

nlp = spacy.load("en_core_web_sm")

# %%
# process and show tokens
nlp_sentence = nlp(st)

for token in nlp_sentence:
    print (token.text, token.pos_, end = " | ") # sentence use and separation

# counting tokens
print("\n\n Number of tokens: ", len(nlp_sentence))
# Out:
# 20116 NUM | 2nd ADJ | MABE ADJ | linfsnoatiional ADJ | Oonfiansnce PROPN | on ADP | Oomypiitien PROPN | and CCONJ | Oonotiimniicatiions PROPN |
#  SPACE | Network PROPN | ! PUNCT | Diaffic PROPN | Classification PROPN | Nechniiques PROPN | and CCONJ | Coniparative PROPN | Aljalysis PROPN |
#  SPACE | Machine NOUN | earning VERB | Algorithms PROPN |
#  SPACE | Shalfig PROPN | , PUNCT | Xitangzhian PROPN | Yity PROPN | AlsiiflAlli PROPN | Daghianil PROPN | , PUNCT | ( PUNCT | Oo ADJ | ‘ PUNCT | Yao PROPN | , PUNCT | Niabiin PROPN | Kicniam PROPN | Keon PROPN | , PUNCT | loudill PROPN | Albldessannia PROPN |
#  SPACE | Schoo PROPN | ! PUNCT | of ADP | Con@jatén PROPN | Science PROPN | anid PROPN | Nechinology PROPN | , PUNCT |
#  SPACE | Hiaecbin PROPN | Iiiitifate PROPN | of ADP | Nechinology PROPN | , PUNCT |
#  SPACE | Harbin PROPN | 15001 NUM | PR PROPN | ) PUNCT | , PUNCT | China PROPN |
#  SPACE | e NOUN | - NOUN | nhiaili NOUN | ( PUNCT | jmubanmhadshatiq PROPN | , PUNCT | yw X | asiflaghari PROPN | , PUNCT | Lfjao PROPN | , PUNCT | Karhisabin PROPN | , PUNCT | fsudiDdbdessamiall NOUN | @hit.eda.cn NOUN |
#
#  SPACE | bstroci NOUN | — PUNCT | Netwonk PROPN | Minaftic PROPN | Olassifibation PROPN | is AUX | a DET | cenfnal ADJ | fopic NOUN | fechnique NOUN | gives VERB | @ccurafe PROPN | resolts NOUN | jin PROPN | mefvabrk PROPN | ) PUNCT | traffic NOUN |
#
#  Number of tokens:  97

# %%
# using function defined in support functions section

create_tokenize(st)
# Out:
# 20116 NUM | 2nd ADJ | MABE ADJ | linfsnoatiional ADJ | Oonfiansnce PROPN | on ADP | Oomypiitien PROPN | and CCONJ | Oonotiimniicatiions PROPN |
#  SPACE | Network PROPN | ! PUNCT | Diaffic PROPN | Classification PROPN | Nechniiques PROPN | and CCONJ | Coniparative PROPN | Aljalysis PROPN |
#  SPACE | Machine NOUN | earning VERB | Algorithms PROPN |
#  SPACE | Shalfig PROPN | , PUNCT | Xitangzhian PROPN | Yity PROPN | AlsiiflAlli PROPN | Daghianil PROPN | , PUNCT | ( PUNCT | Oo ADJ | ‘ PUNCT | Yao PROPN | , PUNCT | Niabiin PROPN | Kicniam PROPN | Keon PROPN | , PUNCT | loudill PROPN | Albldessannia PROPN |
#  SPACE | Schoo PROPN | ! PUNCT | of ADP | Con@jatén PROPN | Science PROPN | anid PROPN | Nechinology PROPN | , PUNCT |
#  SPACE | Hiaecbin PROPN | Iiiitifate PROPN | of ADP | Nechinology PROPN | , PUNCT |
#  SPACE | Harbin PROPN | 15001 NUM | PR PROPN | ) PUNCT | , PUNCT | China PROPN |
#  SPACE | e NOUN | - NOUN | nhiaili NOUN | ( PUNCT | jmubanmhadshatiq PROPN | , PUNCT | yw X | asiflaghari PROPN | , PUNCT | Lfjao PROPN | , PUNCT | Karhisabin PROPN | , PUNCT | fsudiDdbdessamiall NOUN | @hit.eda.cn NOUN |
#
#  SPACE | bstroci NOUN | — PUNCT | Netwonk PROPN | Minaftic PROPN | Olassifibation PROPN | is AUX | a DET | cenfnal ADJ | fopic NOUN | fechnique NOUN | gives VERB | @ccurafe PROPN | resolts NOUN | jin PROPN | mefvabrk PROPN | ) PUNCT | traffic NOUN |
#
#  Number of tokens:  97

# %% [markdown]
# ### Stopword

# %%
# loading whats reqired
nltk.download('punkt_tab')

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/sebszmytka/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebszmytka/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# #### NLTK

# %%
# using NLTK

print("\n >>> stop words with NLTK \n")

st_tokens = word_tokenize(st)

tokens_without_sw = [word for word in st_tokens if not word in stopwords.words()]

print(tokens_without_sw)

print("\n",len(tokens_without_sw))
# Out:
#  >>> stop words with NLTK
#
# ['20116', '2nd', 'MABE', 'linfsnoatiional', 'Oonfiansnce', 'Oomypiitien', 'Oonotiimniicatiions', 'Network', '!', 'Diaffic', 'Classification', 'Nechniiques', 'Coniparative', 'Aljalysis', 'Machine', 'earning', 'Algorithms', 'Shalfig', ',', 'Xitangzhian', 'Yity', 'AlsiiflAlli', 'Daghianil', ',', '(', 'Oo', '‘', 'Yao', ',', 'Niabiin', 'Kicniam', 'Keon', ',', 'loudill', 'Albldessannia', 'Schoo', '!', 'Con', '@', 'jatén', 'Science', 'anid', 'Nechinology', ',', 'Hiaecbin', 'Iiiitifate', 'Nechinology', ',', 'Harbin', '15001', 'PR', ')', ',', 'China', 'e-nhiaili', '(', 'jmubanmhadshatiq', ',', 'yw', 'asiflaghari', ',', 'Lfjao', ',', 'Karhisabin', ',', 'fsudiDdbdessamiall', '@', 'hit.eda.cn', 'bstroci', '—', 'Netwonk', 'Minaftic', 'Olassifibation', 'cenfnal', 'fopic', 'fechnique', '@', 'ccurafe', 'resolts', 'mefvabrk', ')', 'traffic']
#
#  82

# %% [markdown]
# #### spaCy

# %%
# using spaCy

sp = spacy.load("en_core_web_sm")

sp_stopwords = sp.Defaults.stop_words

print("\n >>> stop words with spaCy for comparasment \n")

sw_output = stopwords_spacy(st, verbose=True)
# Out:
#  >>> stop words with spaCy for comparasment
#
#
#  >>> Tokens without stopwords:
# ['20116', '2nd', 'MABE', 'linfsnoatiional', 'Oonfiansnce', 'Oomypiitien', 'Oonotiimniicatiions', 'Network', '!', 'Diaffic', 'Classification', 'Nechniiques', 'Coniparative', 'Aljalysis', 'Machine', 'earning', 'Algorithms', 'Shalfig', ',', 'Xitangzhian', 'Yity', 'AlsiiflAlli', 'Daghianil', ',', '(', 'Oo', '‘', 'Yao', ',', 'Niabiin', 'Kicniam', 'Keon', ',', 'loudill', 'Albldessannia', 'Schoo', '!', 'Con', '@', 'jatén', 'Science', 'anid', 'Nechinology', ',', 'Hiaecbin', 'Iiiitifate', 'Nechinology', ',', 'Harbin', '15001', 'PR', ')', ',', 'China', 'e-nhiaili', '(', 'jmubanmhadshatiq', ',', 'yw', 'asiflaghari', ',', 'Lfjao', ',', 'Karhisabin', ',', 'fsudiDdbdessamiall', '@', 'hit.eda.cn', 'bstroci', '—', 'Netwonk', 'Minaftic', 'Olassifibation', 'cenfnal', 'fopic', 'fechnique', 'gives', '@', 'ccurafe', 'resolts', 'jin', 'mefvabrk', ')', 'traffic']
#
#  >>> Token count: 84

# %% [markdown]
# #### larger text for comparasment

# %%
fulltxt = word_tokenize(st_full)
 
# NLTK
tokens_full = [word for word in fulltxt if not word in stopwords.words()]

print("\n NLTK count: ",len(tokens_full))

# spaCy

tokens_full_sp =[ word for word in fulltxt if not word in sp_stopwords]


print("\n spaCY count: ",len(tokens_full_sp))
# Out:
#  NLTK count:  2630
#
#  spaCY count:  2735

# %% [markdown]
# #### Joining tokens

# %%
jtokens = (" ").join(tokens_without_sw)
print(jtokens)
# Out:
# 20116 2nd MABE linfsnoatiional Oonfiansnce Oomypiitien Oonotiimniicatiions Network ! Diaffic Classification Nechniiques Coniparative Aljalysis Machine earning Algorithms Shalfig , Xitangzhian Yity AlsiiflAlli Daghianil , ( Oo ‘ Yao , Niabiin Kicniam Keon , loudill Albldessannia Schoo ! Con @ jatén Science anid Nechinology , Hiaecbin Iiiitifate Nechinology , Harbin 15001 PR ) , China e-nhiaili ( jmubanmhadshatiq , yw asiflaghari , Lfjao , Karhisabin , fsudiDdbdessamiall @ hit.eda.cn bstroci — Netwonk Minaftic Olassifibation cenfnal fopic fechnique @ ccurafe resolts mefvabrk ) traffic

# %%
### adding stop words to the list

# %%
print("\n >> Elenents in stopword list: ",len(stopwords.words('english')), "\n") # how long is the list
print(stopwords.words('english')) # just to see whats in the list

new_stopwords = stopwords.words('english')
new_stopwords.append('NLP')

new_stopwords.append('>')

print("\n >>> New stopwords list\n")

print("Elements in new stopword list: ",len(new_stopwords), "\n")

print(new_stopwords)
# Out:
#  >> Elenents in stopword list:  198
#
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]
#
#  >>> New stopwords list
#
# Elements in new stopword list:  200
#
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've", 'NLP', '>']

# %% [markdown]
# ## Stemming
# extracting the root of the word

# %%
porter_stemmer = PorterStemmer()
st_port = st.split() # conver to list of words

for word in st_port:
    print(word + " ------> " + porter_stemmer.stem(word))
# Out:
# 20116 ------> 20116
# 2nd ------> 2nd
# MABE ------> mabe
# linfsnoatiional ------> linfsnoatiion
# Oonfiansnce ------> oonfiansnc
# on ------> on
# Oomypiitien ------> oomypiitien
# and ------> and
# Oonotiimniicatiions ------> oonotiimniicatiion
# Network! ------> network!
# Diaffic ------> diaffic
# Classification ------> classif
# Nechniiques ------> nechniiqu
# and ------> and
# Coniparative ------> conipar
# Aljalysis ------> aljalysi
# Machine ------> machin
# earning ------> earn
# Algorithms ------> algorithm
# Shalfig, ------> shalfig,
# Xitangzhian ------> xitangzhian
# Yity ------> yiti
# AlsiiflAlli ------> alsiifl
# Daghianil, ------> daghianil,
# (Oo ------> (oo
# ‘Yao, ------> ‘yao,
# Niabiin ------> niabiin
# Kicniam ------> kicniam
# Keon, ------> keon,
# loudill ------> loudil
# Albldessannia ------> albldessannia
# Schoo! ------> schoo!
# of ------> of
# Con@jatén ------> con@jatén
# Science ------> scienc
# anid ------> anid
# Nechinology, ------> nechinology,
# Hiaecbin ------> hiaecbin
# Iiiitifate ------> iiiitif
# of ------> of
# Nechinology, ------> nechinology,
# Harbin ------> harbin
# 15001 ------> 15001
# PR), ------> pr),
# China ------> china
# e-nhiaili ------> e-nhiaili
# (jmubanmhadshatiq, ------> (jmubanmhadshatiq,
# yw ------> yw
# asiflaghari, ------> asiflaghari,
# Lfjao, ------> lfjao,
# Karhisabin, ------> karhisabin,
# fsudiDdbdessamiall ------> fsudiddbdessamial
# @hit.eda.cn ------> @hit.eda.cn
# bstroci—Netwonk ------> bstroci—netwonk
# Minaftic ------> minaft
# Olassifibation ------> olassifib
# is ------> is
# a ------> a
# cenfnal ------> cenfnal
# fopic ------> fopic
# fechnique ------> fechniqu
# gives ------> give
# @ccurafe ------> @ccuraf
# resolts ------> resolt
# jin ------> jin
# mefvabrk) ------> mefvabrk)
# traffic ------> traffic

# %% [markdown]
# ## Lemmatisation
# compares to stemming, this is method uses gramar/actual dictionary form

# %%
# creating document object

document = nlp(st)

# check for tokens and associated parts-of-speech (POS) tags

for t in document:
    print(t, t.pos_)


# root words analysis

for w in document:
    print(w.text + " |---> " + w.lemma_)

# Lemmatisation versus stemming

for w in document:
    print(w.text + " |---> " + w.lemma_,"\t", w.pos_)

# using function created 

create_lemmatization(st)

# View token tags

for t in document:
    print(f"{t.text:{20}} {t.pos_:{15}}  {t.tag_:{10}} {spacy.explain(t.tag_)}")
# Out:
# 20116 NUM
# 2nd ADJ
# MABE ADJ
# linfsnoatiional ADJ
# Oonfiansnce PROPN
# on ADP
# Oomypiitien PROPN
# and CCONJ
# Oonotiimniicatiions PROPN
#
#  SPACE
# Network PROPN
# ! PUNCT
# Diaffic PROPN
# Classification PROPN
# Nechniiques PROPN
# and CCONJ
# Coniparative PROPN
# Aljalysis PROPN
#
#  SPACE
# Machine NOUN
# earning VERB
# Algorithms PROPN
#
#  SPACE
# Shalfig PROPN
# , PUNCT
# Xitangzhian PROPN
# Yity PROPN
# AlsiiflAlli PROPN
# Daghianil PROPN
# , PUNCT
# ( PUNCT
# Oo ADJ
# ‘ PUNCT
# Yao PROPN
# , PUNCT
# Niabiin PROPN
# Kicniam PROPN
# Keon PROPN
# , PUNCT
# loudill PROPN
# Albldessannia PROPN
#
#  SPACE
# Schoo PROPN
# ! PUNCT
# of ADP
# Con@jatén PROPN
# Science PROPN
# anid PROPN
# Nechinology PROPN
# , PUNCT
#
#  SPACE
# Hiaecbin PROPN
# Iiiitifate PROPN
# of ADP
# Nechinology PROPN
# , PUNCT
#
#  SPACE
# Harbin PROPN
# 15001 NUM
# PR PROPN
# ) PUNCT
# , PUNCT
# China PROPN
#
#  SPACE
# e NOUN
# - NOUN
# nhiaili NOUN
# ( PUNCT
# jmubanmhadshatiq PROPN
# , PUNCT
# yw X
# asiflaghari PROPN
# , PUNCT
# Lfjao PROPN
# , PUNCT
# Karhisabin PROPN
# , PUNCT
# fsudiDdbdessamiall NOUN
# @hit.eda.cn NOUN
#
#
#  SPACE
# bstroci NOUN
# — PUNCT
# Netwonk PROPN
# Minaftic PROPN
# Olassifibation PROPN
# is AUX
# a DET
# cenfnal ADJ
# fopic NOUN
# fechnique NOUN
# gives VERB
# @ccurafe PROPN
# resolts NOUN
# jin PROPN
# mefvabrk PROPN
# ) PUNCT
# traffic NOUN
# 20116 |---> 20116
# 2nd |---> 2nd
# MABE |---> mabe
# linfsnoatiional |---> linfsnoatiional
# Oonfiansnce |---> Oonfiansnce
# on |---> on
# Oomypiitien |---> Oomypiitien
# and |---> and
# Oonotiimniicatiions |---> Oonotiimniicatiions
#
#  |--->
#
# Network |---> Network
# ! |---> !
# Diaffic |---> Diaffic
# Classification |---> Classification
# Nechniiques |---> Nechniiques
# and |---> and
# Coniparative |---> Coniparative
# Aljalysis |---> Aljalysis
#
#  |--->
#
# Machine |---> machine
# earning |---> earn
# Algorithms |---> Algorithms
#
#  |--->
#
# Shalfig |---> Shalfig
# , |---> ,
# Xitangzhian |---> Xitangzhian
# Yity |---> Yity
# AlsiiflAlli |---> AlsiiflAlli
# Daghianil |---> Daghianil
# , |---> ,
# ( |---> (
# Oo |---> oo
# ‘ |---> '
# Yao |---> Yao
# , |---> ,
# Niabiin |---> Niabiin
# Kicniam |---> Kicniam
# Keon |---> Keon
# , |---> ,
# loudill |---> loudill
# Albldessannia |---> Albldessannia
#
#  |--->
#
# Schoo |---> Schoo
# ! |---> !
# of |---> of
# Con@jatén |---> Con@jatén
# Science |---> Science
# anid |---> anid
# Nechinology |---> Nechinology
# , |---> ,
#
#  |--->
#
# Hiaecbin |---> Hiaecbin
# Iiiitifate |---> Iiiitifate
# of |---> of
# Nechinology |---> Nechinology
# , |---> ,
#
#  |--->
#
# Harbin |---> Harbin
# 15001 |---> 15001
# PR |---> PR
# ) |---> )
# , |---> ,
# China |---> China
#
#  |--->
#
# e |---> e
# - |---> -
# nhiaili |---> nhiaili
# ( |---> (
# jmubanmhadshatiq |---> jmubanmhadshatiq
# , |---> ,
# yw |---> yw
# asiflaghari |---> asiflaghari
# , |---> ,
# Lfjao |---> Lfjao
# , |---> ,
# Karhisabin |---> Karhisabin
# , |---> ,
# fsudiDdbdessamiall |---> fsudiddbdessamiall
# @hit.eda.cn |---> @hit.eda.cn
#
#
#  |--->
#
#
# bstroci |---> bstroci
# — |---> —
# Netwonk |---> Netwonk
# Minaftic |---> Minaftic
# Olassifibation |---> Olassifibation
# is |---> be
# a |---> a
# cenfnal |---> cenfnal
# fopic |---> fopic
# fechnique |---> fechnique
# gives |---> give
# @ccurafe |---> @ccurafe
# resolts |---> resolt
# jin |---> jin
# mefvabrk |---> mefvabrk
# ) |---> )
# traffic |---> traffic
# 20116 |---> 20116 	 NUM
# 2nd |---> 2nd 	 ADJ
# MABE |---> mabe 	 ADJ
# linfsnoatiional |---> linfsnoatiional 	 ADJ
# Oonfiansnce |---> Oonfiansnce 	 PROPN
# on |---> on 	 ADP
# Oomypiitien |---> Oomypiitien 	 PROPN
# and |---> and 	 CCONJ
# Oonotiimniicatiions |---> Oonotiimniicatiions 	 PROPN
#
#  |--->
#  	 SPACE
# Network |---> Network 	 PROPN
# ! |---> ! 	 PUNCT
# Diaffic |---> Diaffic 	 PROPN
# Classification |---> Classification 	 PROPN
# Nechniiques |---> Nechniiques 	 PROPN
# and |---> and 	 CCONJ
# Coniparative |---> Coniparative 	 PROPN
# Aljalysis |---> Aljalysis 	 PROPN
#
#  |--->
#  	 SPACE
# Machine |---> machine 	 NOUN
# earning |---> earn 	 VERB
# Algorithms |---> Algorithms 	 PROPN
#
#  |--->
#  	 SPACE
# Shalfig |---> Shalfig 	 PROPN
# , |---> , 	 PUNCT
# Xitangzhian |---> Xitangzhian 	 PROPN
# Yity |---> Yity 	 PROPN
# AlsiiflAlli |---> AlsiiflAlli 	 PROPN
# Daghianil |---> Daghianil 	 PROPN
# , |---> , 	 PUNCT
# ( |---> ( 	 PUNCT
# Oo |---> oo 	 ADJ
# ‘ |---> ' 	 PUNCT
# Yao |---> Yao 	 PROPN
# , |---> , 	 PUNCT
# Niabiin |---> Niabiin 	 PROPN
# Kicniam |---> Kicniam 	 PROPN
# Keon |---> Keon 	 PROPN
# , |---> , 	 PUNCT
# loudill |---> loudill 	 PROPN
# Albldessannia |---> Albldessannia 	 PROPN
#
#  |--->
#  	 SPACE
# Schoo |---> Schoo 	 PROPN
# ! |---> ! 	 PUNCT
# of |---> of 	 ADP
# Con@jatén |---> Con@jatén 	 PROPN
# Science |---> Science 	 PROPN
# anid |---> anid 	 PROPN
# Nechinology |---> Nechinology 	 PROPN
# , |---> , 	 PUNCT
#
#  |--->
#  	 SPACE
# Hiaecbin |---> Hiaecbin 	 PROPN
# Iiiitifate |---> Iiiitifate 	 PROPN
# of |---> of 	 ADP
# Nechinology |---> Nechinology 	 PROPN
# , |---> , 	 PUNCT
#
#  |--->
#  	 SPACE
# Harbin |---> Harbin 	 PROPN
# 15001 |---> 15001 	 NUM
# PR |---> PR 	 PROPN
# ) |---> ) 	 PUNCT
# , |---> , 	 PUNCT
# China |---> China 	 PROPN
#
#  |--->
#  	 SPACE
# e |---> e 	 NOUN
# - |---> - 	 NOUN
# nhiaili |---> nhiaili 	 NOUN
# ( |---> ( 	 PUNCT
# jmubanmhadshatiq |---> jmubanmhadshatiq 	 PROPN
# , |---> , 	 PUNCT
# yw |---> yw 	 X
# asiflaghari |---> asiflaghari 	 PROPN
# , |---> , 	 PUNCT
# Lfjao |---> Lfjao 	 PROPN
# , |---> , 	 PUNCT
# Karhisabin |---> Karhisabin 	 PROPN
# , |---> , 	 PUNCT
# fsudiDdbdessamiall |---> fsudiddbdessamiall 	 NOUN
# @hit.eda.cn |---> @hit.eda.cn 	 NOUN
#
#
#  |--->
#
#  	 SPACE
# bstroci |---> bstroci 	 NOUN
# — |---> — 	 PUNCT
# Netwonk |---> Netwonk 	 PROPN
# Minaftic |---> Minaftic 	 PROPN
# Olassifibation |---> Olassifibation 	 PROPN
# is |---> be 	 AUX
# a |---> a 	 DET
# cenfnal |---> cenfnal 	 ADJ
# fopic |---> fopic 	 NOUN
# fechnique |---> fechnique 	 NOUN
# gives |---> give 	 VERB
# @ccurafe |---> @ccurafe 	 PROPN
# resolts |---> resolt 	 NOUN
# jin |---> jin 	 PROPN
# mefvabrk |---> mefvabrk 	 PROPN
# ) |---> ) 	 PUNCT
# traffic |---> traffic 	 NOUN
# 20116           20116
# 2nd             2nd
# MABE            mabe
# linfsnoatiional linfsnoatiional
# Oonfiansnce     Oonfiansnce
# on              on
# Oomypiitien     Oomypiitien
# and             and
# Oonotiimniicatiions Oonotiimniicatiions
#
#
#
# Network         Network
# !               !
# Diaffic         Diaffic
# Classification  Classification
# Nechniiques     Nechniiques
# and             and
# Coniparative    Coniparative
# Aljalysis       Aljalysis
#
#
#
# Machine         machine
# earning         earn
# Algorithms      Algorithms
#
#
#
# Shalfig         Shalfig
# ,               ,
# Xitangzhian     Xitangzhian
# Yity            Yity
# AlsiiflAlli     AlsiiflAlli
# Daghianil       Daghianil
# ,               ,
# (               (
# Oo              oo
# ‘               '
# Yao             Yao
# ,               ,
# Niabiin         Niabiin
# Kicniam         Kicniam
# Keon            Keon
# ,               ,
# loudill         loudill
# Albldessannia   Albldessannia
#
#
#
# Schoo           Schoo
# !               !
# of              of
# Con@jatén       Con@jatén
# Science         Science
# anid            anid
# Nechinology     Nechinology
# ,               ,
#
#
#
# Hiaecbin        Hiaecbin
# Iiiitifate      Iiiitifate
# of              of
# Nechinology     Nechinology
# ,               ,
#
#
#
# Harbin          Harbin
# 15001           15001
# PR              PR
# )               )
# ,               ,
# China           China
#
#
#
# e               e
# -               -
# nhiaili         nhiaili
# (               (
# jmubanmhadshatiq jmubanmhadshatiq
# ,               ,
# yw              yw
# asiflaghari     asiflaghari
# ,               ,
# Lfjao           Lfjao
# ,               ,
# Karhisabin      Karhisabin
# ,               ,
# fsudiDdbdessamiall fsudiddbdessamiall
# @hit.eda.cn     @hit.eda.cn
#
#
#
#
#
# bstroci         bstroci
# —               —
# Netwonk         Netwonk
# Minaftic        Minaftic
# Olassifibation  Olassifibation
# is              be
# a               a
# cenfnal         cenfnal
# fopic           fopic
# fechnique       fechnique
# gives           give
# @ccurafe        @ccurafe
# resolts         resolt
# jin             jin
# mefvabrk        mefvabrk
# )               )
# traffic         traffic
# 20116                NUM              CD         cardinal number
# 2nd                  ADJ              JJ         adjective (English), other noun-modifier (Chinese)
# MABE                 ADJ              JJ         adjective (English), other noun-modifier (Chinese)
# linfsnoatiional      ADJ              JJ         adjective (English), other noun-modifier (Chinese)
# Oonfiansnce          PROPN            NNP        noun, proper singular
# on                   ADP              IN         conjunction, subordinating or preposition
# Oomypiitien          PROPN            NNP        noun, proper singular
# and                  CCONJ            CC         conjunction, coordinating
# Oonotiimniicatiions  PROPN            NNP        noun, proper singular
#
#                     SPACE            _SP        whitespace
# Network              PROPN            NNP        noun, proper singular
# !                    PUNCT            .          punctuation mark, sentence closer
# Diaffic              PROPN            NNP        noun, proper singular
# Classification       PROPN            NNP        noun, proper singular
# Nechniiques          PROPN            NNPS       noun, proper plural
# and                  CCONJ            CC         conjunction, coordinating
# Coniparative         PROPN            NNP        noun, proper singular
# Aljalysis            PROPN            NNP        noun, proper singular
#
#                     SPACE            _SP        whitespace
# Machine              NOUN             NN         noun, singular or mass
# earning              VERB             VBG        verb, gerund or present participle
# Algorithms           PROPN            NNP        noun, proper singular
#
#                     SPACE            _SP        whitespace
# Shalfig              PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# Xitangzhian          PROPN            NNP        noun, proper singular
# Yity                 PROPN            NNP        noun, proper singular
# AlsiiflAlli          PROPN            NNP        noun, proper singular
# Daghianil            PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# (                    PUNCT            -LRB-      left round bracket
# Oo                   ADJ              JJ         adjective (English), other noun-modifier (Chinese)
# ‘                    PUNCT            ``         opening quotation mark
# Yao                  PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# Niabiin              PROPN            NNP        noun, proper singular
# Kicniam              PROPN            NNP        noun, proper singular
# Keon                 PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# loudill              PROPN            NNP        noun, proper singular
# Albldessannia        PROPN            NNP        noun, proper singular
#
#                     SPACE            _SP        whitespace
# Schoo                PROPN            NNP        noun, proper singular
# !                    PUNCT            .          punctuation mark, sentence closer
# of                   ADP              IN         conjunction, subordinating or preposition
# Con@jatén            PROPN            NNP        noun, proper singular
# Science              PROPN            NNP        noun, proper singular
# anid                 PROPN            NNP        noun, proper singular
# Nechinology          PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
#
#                     SPACE            _SP        whitespace
# Hiaecbin             PROPN            NNP        noun, proper singular
# Iiiitifate           PROPN            NNP        noun, proper singular
# of                   ADP              IN         conjunction, subordinating or preposition
# Nechinology          PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
#
#                     SPACE            _SP        whitespace
# Harbin               PROPN            NNP        noun, proper singular
# 15001                NUM              CD         cardinal number
# PR                   PROPN            NNP        noun, proper singular
# )                    PUNCT            -RRB-      right round bracket
# ,                    PUNCT            ,          punctuation mark, comma
# China                PROPN            NNP        noun, proper singular
#
#                     SPACE            _SP        whitespace
# e                    NOUN             NN         noun, singular or mass
# -                    NOUN             NN         noun, singular or mass
# nhiaili              NOUN             NN         noun, singular or mass
# (                    PUNCT            -LRB-      left round bracket
# jmubanmhadshatiq     PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# yw                   X                FW         foreign word
# asiflaghari          PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# Lfjao                PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# Karhisabin           PROPN            NNP        noun, proper singular
# ,                    PUNCT            ,          punctuation mark, comma
# fsudiDdbdessamiall   NOUN             NN         noun, singular or mass
# @hit.eda.cn          NOUN             NNS        noun, plural
#
#
#                    SPACE            _SP        whitespace
# bstroci              NOUN             NN         noun, singular or mass
# —                    PUNCT            :          punctuation mark, colon or ellipsis
# Netwonk              PROPN            NNP        noun, proper singular
# Minaftic             PROPN            NNP        noun, proper singular
# Olassifibation       PROPN            NNP        noun, proper singular
# is                   AUX              VBZ        verb, 3rd person singular present
# a                    DET              DT         determiner
# cenfnal              ADJ              JJ         adjective (English), other noun-modifier (Chinese)
# fopic                NOUN             NN         noun, singular or mass
# fechnique            NOUN             NN         noun, singular or mass
# gives                VERB             VBZ        verb, 3rd person singular present
# @ccurafe             PROPN            NNP        noun, proper singular
# resolts              NOUN             NNS        noun, plural
# jin                  PROPN            NNP        noun, proper singular
# mefvabrk             PROPN            NNP        noun, proper singular
# )                    PUNCT            -RRB-      right round bracket
# traffic              NOUN             NN         noun, singular or mass

# %%
# POS Tags 

print("\n >>> spaCy predicting the use of tokens in the sentence and can also find is verb is present or past tense \n")

for t in document:
    print(f" {t.text:{10}} {t.pos_:{10}} {t.tag_:{10}} {spacy.explain(t.tag_):{20}}")

print("\n >>> filtered option for one word \n")

print(f"{document[6].text:{10}} {document[6].pos_:{10}} {document[6].tag_:{10}} {spacy.explain(document[6].tag_):{20}}")

print("\n >>> POS Tag Frequency\n")
fcount = document.count_by(spacy.attrs.POS)
print("\n", fcount, "\n") 

print("\nLooking up ID of the POS tag 100: \n")
document.vocab[100].text

print("\n >>> POS Count Frequency is an disctionary, so checking in:  \n")

for i, fr in fcount.items():
    print(f" {i:{10}} {document.vocab[i].text:{10}} {fr}")

print("\n >>> For more details output we can use spacy.attrs.TAG: \n")

finegrainedPOS = document.count_by(spacy.attrs.TAG)

for i, fr in sorted (finegrainedPOS.items()):
    print(f" {i:{20}} {document.vocab[i].text:{10}} {fr}")

print("\n >>> Visualization of POS tags using displacy module: \n")

displacy.render(document, style='dep', jupyter=True, options={'distance': 120})
# Out:
#  >>> spaCy predicting the use of tokens in the sentence and can also find is verb is present or past tense
#
#  20116      NUM        CD         cardinal number
#  2nd        ADJ        JJ         adjective (English), other noun-modifier (Chinese)
#  MABE       ADJ        JJ         adjective (English), other noun-modifier (Chinese)
#  linfsnoatiional ADJ        JJ         adjective (English), other noun-modifier (Chinese)
#  Oonfiansnce PROPN      NNP        noun, proper singular
#  on         ADP        IN         conjunction, subordinating or preposition
#  Oomypiitien PROPN      NNP        noun, proper singular
#  and        CCONJ      CC         conjunction, coordinating
#  Oonotiimniicatiions PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
#  Network    PROPN      NNP        noun, proper singular
#  !          PUNCT      .          punctuation mark, sentence closer
#  Diaffic    PROPN      NNP        noun, proper singular
#  Classification PROPN      NNP        noun, proper singular
#  Nechniiques PROPN      NNPS       noun, proper plural
#  and        CCONJ      CC         conjunction, coordinating
#  Coniparative PROPN      NNP        noun, proper singular
#  Aljalysis  PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
#  Machine    NOUN       NN         noun, singular or mass
#  earning    VERB       VBG        verb, gerund or present participle
#  Algorithms PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
#  Shalfig    PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  Xitangzhian PROPN      NNP        noun, proper singular
#  Yity       PROPN      NNP        noun, proper singular
#  AlsiiflAlli PROPN      NNP        noun, proper singular
#  Daghianil  PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  (          PUNCT      -LRB-      left round bracket
#  Oo         ADJ        JJ         adjective (English), other noun-modifier (Chinese)
#  ‘          PUNCT      ``         opening quotation mark
#  Yao        PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  Niabiin    PROPN      NNP        noun, proper singular
#  Kicniam    PROPN      NNP        noun, proper singular
#  Keon       PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  loudill    PROPN      NNP        noun, proper singular
#  Albldessannia PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
#  Schoo      PROPN      NNP        noun, proper singular
#  !          PUNCT      .          punctuation mark, sentence closer
#  of         ADP        IN         conjunction, subordinating or preposition
#  Con@jatén  PROPN      NNP        noun, proper singular
#  Science    PROPN      NNP        noun, proper singular
#  anid       PROPN      NNP        noun, proper singular
#  Nechinology PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#
#           SPACE      _SP        whitespace
#  Hiaecbin   PROPN      NNP        noun, proper singular
#  Iiiitifate PROPN      NNP        noun, proper singular
#  of         ADP        IN         conjunction, subordinating or preposition
#  Nechinology PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#
#           SPACE      _SP        whitespace
#  Harbin     PROPN      NNP        noun, proper singular
#  15001      NUM        CD         cardinal number
#  PR         PROPN      NNP        noun, proper singular
#  )          PUNCT      -RRB-      right round bracket
#  ,          PUNCT      ,          punctuation mark, comma
#  China      PROPN      NNP        noun, proper singular
#
#           SPACE      _SP        whitespace
#  e          NOUN       NN         noun, singular or mass
#  -          NOUN       NN         noun, singular or mass
#  nhiaili    NOUN       NN         noun, singular or mass
#  (          PUNCT      -LRB-      left round bracket
#  jmubanmhadshatiq PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  yw         X          FW         foreign word
#  asiflaghari PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  Lfjao      PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  Karhisabin PROPN      NNP        noun, proper singular
#  ,          PUNCT      ,          punctuation mark, comma
#  fsudiDdbdessamiall NOUN       NN         noun, singular or mass
#  @hit.eda.cn NOUN       NNS        noun, plural
#
#
#          SPACE      _SP        whitespace
#  bstroci    NOUN       NN         noun, singular or mass
#  —          PUNCT      :          punctuation mark, colon or ellipsis
#  Netwonk    PROPN      NNP        noun, proper singular
#  Minaftic   PROPN      NNP        noun, proper singular
#  Olassifibation PROPN      NNP        noun, proper singular
#  is         AUX        VBZ        verb, 3rd person singular present
#  a          DET        DT         determiner
#  cenfnal    ADJ        JJ         adjective (English), other noun-modifier (Chinese)
#  fopic      NOUN       NN         noun, singular or mass
#  fechnique  NOUN       NN         noun, singular or mass
#  gives      VERB       VBZ        verb, 3rd person singular present
#  @ccurafe   PROPN      NNP        noun, proper singular
#  resolts    NOUN       NNS        noun, plural
#  jin        PROPN      NNP        noun, proper singular
#  mefvabrk   PROPN      NNP        noun, proper singular
#  )          PUNCT      -RRB-      right round bracket
#  traffic    NOUN       NN         noun, singular or mass
#
#  >>> filtered option for one word
#
# Oomypiitien PROPN      NNP        noun, proper singular
#
#  >>> POS Tag Frequency
#
#
#  {93: 2, 84: 5, 96: 42, 85: 3, 89: 2, 103: 8, 97: 19, 92: 11, 100: 2, 101: 1, 87: 1, 90: 1}
#
#
# Looking up ID of the POS tag 100:
#
#
#  >>> POS Count Frequency is an disctionary, so checking in:
#
#          93 NUM        2
#          84 ADJ        5
#          96 PROPN      42
#          85 ADP        3
#          89 CCONJ      2
#         103 SPACE      8
#          97 PUNCT      19
#          92 NOUN       11
#         100 VERB       2
#         101 X          1
#          87 AUX        1
#          90 DET        1
#
#  >>> For more details output we can use spacy.attrs.TAG:
#
#    783433942507015291 NNS        2
#   1292078113972184607 IN         3
#   1534113631682161808 VBG        1
#   2465883113906300949 -RRB-      2
#   2593208677638477497 ,          11
#   4969857429396651903 ``         1
#   6893682062797376370 _SP        8
#   8427216679587749980 CD         2
#  10554686591937588953 JJ         5
#  11233576250605462493 NNPS       1
#  11532473245541075862 :          1
#  12646065887601541794 .          2
#  13927759927860985106 VBZ        2
#  15267657372422890137 DT         1
#  15308085513773655218 NN         9
#  15401913388386482565 FW         1
#  15794550382381185553 NNP        41
#  17111077179131903759 -LRB-      2
#  17571114184892886314 CC         2
#
#  >>> Visualization of POS tags using displacy module:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3d07cadc740f4dab8a414944b73b1f3c-0" class="displacy" width="9290" height="977.0" direction="ltr" style="max-width: none; height: 977.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">20116</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">2nd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">MABE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">linfsnoatiional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Oonfiansnce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Oomypiitien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Oonotiimniicatiions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Network!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Diaffic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Classification</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Nechniiques</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Coniparative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Aljalysis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">earning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Algorithms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">Shalfig,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">Xitangzhian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">Yity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">AlsiiflAlli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">Daghianil, (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">Oo ‘</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">Yao,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">Niabiin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" f

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# ### TF-IDF
#
# word/term frequency in the document (better demonstrated in the scikit-learn pipe line)

# %%
vectorizer = TfidfVectorizer()

x = vectorizer.fit_transform([st])

# get feature and scores
feature_names = vectorizer.get_feature_names_out()
scores = np.asarray(x.mean(axis=0)).flatten()
top_indices = np.argsort(scores)[::-1][:10]

print(x)

print("\n Top 10 terms")
for i in top_indices:
    print(f"  {feature_names[i]:{20}} {scores[i]:.4f}")
# Out:
#   (np.int32(0), np.int32(1))	0.11470786693528087
#   (np.int32(0), np.int32(2))	0.11470786693528087
#   (np.int32(0), np.int32(40))	0.11470786693528087
#   (np.int32(0), np.int32(38))	0.11470786693528087
#   (np.int32(0), np.int32(55))	0.11470786693528087
#   (np.int32(0), np.int32(52))	0.11470786693528087
#   (np.int32(0), np.int32(54))	0.11470786693528087
#   (np.int32(0), np.int32(7))	0.22941573387056174
#   (np.int32(0), np.int32(56))	0.11470786693528087
#   (np.int32(0), np.int32(47))	0.11470786693528087
#   (np.int32(0), np.int32(19))	0.11470786693528087
#   (np.int32(0), np.int32(14))	0.11470786693528087
#   (np.int32(0), np.int32(45))	0.11470786693528087
#   (np.int32(0), np.int32(17))	0.11470786693528087
#   (np.int32(0), np.int32(5))	0.11470786693528087
#   (np.int32(0), np.int32(41))	0.11470786693528087
#   (np.int32(0), np.int32(20))	0.11470786693528087
#   (np.int32(0), np.int32(4))	0.11470786693528087
#   (np.int32(0), np.int32(61))	0.11470786693528087
#   (np.int32(0), np.int32(63))	0.11470786693528087
#   (np.int32(0), np.int32(65))	0.11470786693528087
#   (np.int32(0), np.int32(6))	0.11470786693528087
#   (np.int32(0), np.int32(18))	0.11470786693528087
#   (np.int32(0), np.int32(53))	0.11470786693528087
#   (np.int32(0), np.int32(64))	0.11470786693528087
#   :	:
#   (np.int32(0), np.int32(13))	0.11470786693528087
#   (np.int32(0), np.int32(48))	0.11470786693528087
#   (np.int32(0), np.int32(33))	0.11470786693528087
#   (np.int32(0), np.int32(66))	0.11470786693528087
#   (np.int32(0), np.int32(9))	0.11470786693528087
#   (np.int32(0), np.int32(37))	0.11470786693528087
#   (np.int32(0), np.int32(34))	0.11470786693528087
#   (np.int32(0), np.int32(24))	0.11470786693528087
#   (np.int32(0), np.int32(28))	0.11470786693528087
#   (np.int32(0), np.int32(21))	0.11470786693528087
#   (np.int32(0), np.int32(15))	0.11470786693528087
#   (np.int32(0), np.int32(10))	0.11470786693528087
#   (np.int32(0), np.int32(46))	0.11470786693528087
#   (np.int32(0), np.int32(43))	0.11470786693528087
#   (np.int32(0), np.int32(51))	0.11470786693528087
#   (np.int32(0), np.int32(30))	0.11470786693528087
#   (np.int32(0), np.int32(12))	0.11470786693528087
#   (np.int32(0), np.int32(23))	0.11470786693528087
#   (np.int32(0), np.int32(22))	0.11470786693528087
#   (np.int32(0), np.int32(25))	0.11470786693528087
#   (np.int32(0), np.int32(11))	0.11470786693528087
#   (np.int32(0), np.int32(58))	0.11470786693528087
#   (np.int32(0), np.int32(32))	0.11470786693528087
#   (np.int32(0), np.int32(42))	0.11470786693528087
#   (np.int32(0), np.int32(62))	0.11470786693528087
#
#  Top 10 terms
#   of                   0.2294
#   nechinology          0.2294
#   and                  0.2294
#   yw                   0.1147
#   fechnique            0.1147
#   daghianil            0.1147
#   diaffic              0.1147
#   earning              0.1147
#   eda                  0.1147
#   fopic                0.1147

# %% [markdown]
# ### Named Entity Recognition (NER)
# predicting "real world objects" with spaCy

# %%
# iterating over entities found in the document
for ent in document.ents:
    print(f"{ent.text:{30}} {ent.label_:{15}} {spacy.explain(ent.label_)}")

# Visualising NER using displacy
displacy.render(document, style='ent', jupyter=True)
# Out:
# 20116 2nd                      DATE            Absolute or relative dates or periods
# Oomypiitien                    PERSON          People, including fictional
# Oonotiimniicatiions
# Network!   ORG             Companies, agencies, institutions, etc.
# Coniparative Aljalysis
# Machine ORG             Companies, agencies, institutions, etc.
# Algorithms
# Shalfig             ORG             Companies, agencies, institutions, etc.
# Xitangzhian Yity AlsiiflAlli Daghianil PERSON          People, including fictional
# Niabiin Kicniam Keon           PERSON          People, including fictional
# Albldessannia                  GPE             Countries, cities, states
# Hiaecbin Iiiitifate of Nechinology ORG             Companies, agencies, institutions, etc.
# Harbin                         GPE             Countries, cities, states
# 15001                          DATE            Absolute or relative dates or periods
# China                          GPE             Countries, cities, states
# jmubanmhadshatiq               PERSON          People, including fictional
# asiflaghari                    NORP            Nationalities or religious or political groups
# Lfjao                          GPE             Countries, cities, states
# Karhisabin                     GPE             Countries, cities, states
# Netwonk Minaftic Olassifibation ORG             Companies, agencies, institutions, etc.
# jin mefvabrk                   PERSON          People, including fictional
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20116 2nd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  MABE linfsnoatiional Oonfiansnce on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oomypiitien
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oonotiimniicatiions
# Network!
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Diaffic Classification Nechniiques and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coniparative Aljalysis
# Machine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  earning
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithms
# Shalfig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xitangzhian Yity AlsiiflAlli Daghianil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , (Oo ‘Yao,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niabiin Kicniam Keon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , loudill
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Albldessannia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>Schoo! of Con@jatén Science anid Nechinology,<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hiaecbin Iiiitifate of Nechinology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,<br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harbin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  PR),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>e-nhiaili (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jmubanmhadshatiq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , yw
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     asiflaghari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lfjao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karhisabin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , fsudiDdbdessamiall @hit.eda.cn<br><br>bstroci—
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Netwonk Minaftic Olassifibation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a cenfnal fopic fechnique gives @ccurafe resolts
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jin mefvabrk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) traffic</div></span>

# %% [markdown]
# ### Noun Chunks
# extracting meaningful noun phrases

# %%
for chunk in document.noun_chunks:
    print(chunk.text)
# Out:
# 20116 2nd MABE linfsnoatiional Oonfiansnce
# Oomypiitien
# Oonotiimniicatiions
# Network
# Diaffic Classification Nechniiques
# Coniparative Aljalysis
# Machine
# Algorithms
# Shalfig
# Xitangzhian Yity AlsiiflAlli Daghianil
# ‘Yao
# Niabiin Kicniam Keon
# loudill Albldessannia
# Schoo
# Con@jatén Science anid Nechinology
# Hiaecbin Iiiitifate
# Nechinology
# Harbin 15001 PR
# China
# e
# -
# nhiaili
# jmubanmhadshatiq
# yw asiflaghari
# Lfjao
# Karhisabin
# fsudiDdbdessamiall @hit.eda.cn
#
# bstroci
# Netwonk Minaftic Olassifibation
# a cenfnal fopic fechnique
# @ccurafe resolts

# %% [markdown]
# ### Prefix / Suffix
# morphological analysis

# %%
for t in document:
    print(f"{t.text:{20}} prefix: {t.prefix_:{10}} suffix: {t.suffix_}")
# Out:
# 20116                prefix: 2          suffix: 116
# 2nd                  prefix: 2          suffix: 2nd
# MABE                 prefix: M          suffix: ABE
# linfsnoatiional      prefix: l          suffix: nal
# Oonfiansnce          prefix: O          suffix: nce
# on                   prefix: o          suffix: on
# Oomypiitien          prefix: O          suffix: ien
# and                  prefix: a          suffix: and
# Oonotiimniicatiions  prefix: O          suffix: ons
#
#                     prefix:
#           suffix:
#
# Network              prefix: N          suffix: ork
# !                    prefix: !          suffix: !
# Diaffic              prefix: D          suffix: fic
# Classification       prefix: C          suffix: ion
# Nechniiques          prefix: N          suffix: ues
# and                  prefix: a          suffix: and
# Coniparative         prefix: C          suffix: ive
# Aljalysis            prefix: A          suffix: sis
#
#                     prefix:
#           suffix:
#
# Machine              prefix: M          suffix: ine
# earning              prefix: e          suffix: ing
# Algorithms           prefix: A          suffix: hms
#
#                     prefix:
#           suffix:
#
# Shalfig              prefix: S          suffix: fig
# ,                    prefix: ,          suffix: ,
# Xitangzhian          prefix: X          suffix: ian
# Yity                 prefix: Y          suffix: ity
# AlsiiflAlli          prefix: A          suffix: lli
# Daghianil            prefix: D          suffix: nil
# ,                    prefix: ,          suffix: ,
# (                    prefix: (          suffix: (
# Oo                   prefix: O          suffix: Oo
# ‘                    prefix: ‘          suffix: ‘
# Yao                  prefix: Y          suffix: Yao
# ,                    prefix: ,          suffix: ,
# Niabiin              prefix: N          suffix: iin
# Kicniam              prefix: K          suffix: iam
# Keon                 prefix: K          suffix: eon
# ,                    prefix: ,          suffix: ,
# loudill              prefix: l          suffix: ill
# Albldessannia        prefix: A          suffix: nia
#
#                     prefix:
#           suffix:
#
# Schoo                prefix: S          suffix: hoo
# !                    prefix: !          suffix: !
# of                   prefix: o          suffix: of
# Con@jatén            prefix: C          suffix: tén
# Science              prefix: S          suffix: nce
# anid                 prefix: a          suffix: nid
# Nechinology          prefix: N          suffix: ogy
# ,                    prefix: ,          suffix: ,
#
#                     prefix:
#           suffix:
#
# Hiaecbin             prefix: H          suffix: bin
# Iiiitifate           prefix: I          suffix: ate
# of                   prefix: o          suffix: of
# Nechinology          prefix: N          suffix: ogy
# ,                    prefix: ,          suffix: ,
#
#                     prefix:
#           suffix:
#
# Harbin               prefix: H          suffix: bin
# 15001                prefix: 1          suffix: 001
# PR                   prefix: P          suffix: PR
# )                    prefix: )          suffix: )
# ,                    prefix: ,          suffix: ,
# China                prefix: C          suffix: ina
#
#                     prefix:
#           suffix:
#
# e                    prefix: e          suffix: e
# -                    prefix: -          suffix: -
# nhiaili              prefix: n          suffix: ili
# (                    prefix: (          suffix: (
# jmubanmhadshatiq     prefix: j          suffix: tiq
# ,                    prefix: ,          suffix: ,
# yw                   prefix: y          suffix: yw
# asiflaghari          prefix: a          suffix: ari
# ,                    prefix: ,          suffix: ,
# Lfjao                prefix: L          suffix: jao
# ,                    prefix: ,          suffix: ,
# Karhisabin           prefix: K          suffix: bin
# ,                    prefix: ,          suffix: ,
# fsudiDdbdessamiall   prefix: f          suffix: all
# @hit.eda.cn          prefix: @          suffix: .cn
#
#
#                    prefix:
#           suffix:
#
#
# bstroci              prefix: b          suffix: oci
# —                    prefix: —          suffix: —
# Netwonk              prefix: N          suffix: onk
# Minaftic             prefix: M          suffix: tic
# Olassifibation       prefix: O          suffix: ion
# is                   prefix: i          suffix: is
# a                    prefix: a          suffix: a
# cenfnal              prefix: c          suffix: nal
# fopic                prefix: f          suffix: pic
# fechnique            prefix: f          suffix: que
# gives                prefix: g          suffix: ves
# @ccurafe             prefix: @          suffix: afe
# resolts              prefix: r          suffix: lts
# jin                  prefix: j          suffix: jin
# mefvabrk             prefix: m          suffix: brk
# )                    prefix: )          suffix: )
# traffic              prefix: t          suffix: fic

# %% [raw]
# ### Scikit-learn Pipeline
#
# including:
# - extract text
# - clean text
# - stopwords removal
# - CountVectorizer + LDA
# - TF IDF + Logistic Regresion
# - confusion matrix

# %%
# load files

dffiles = load_files("Dataset/images/", extensions=['.png', '.jpg'])
print(dffiles)

# riun pipeline
for d in dffiles:
    npl_pipeline(d)
# Out:
# Found 5 files in 'Dataset/images/'
# ['Dataset/images/IMG_7993.jpg', 'Dataset/images/IMG_7994.jpg', 'Dataset/images/Screenshot 2026-05-13.png', 'Dataset/images/Testi2.png', 'Dataset/images/pdf0.png']
#  >>> Extracted 17 chunks from image
# topic_0: ['potatoes', 'cook', 'chilies', 'minutes', 'add']
# topic_1: ['cup', 'potatoes', 'chopped', 'red', 'heat']
# topic_2: ['brown', 'medium', 'recipe', 'rice', 'add']
# Extracted 17 chunks from image
#
#  Confusion Matrix:
#               topic_0
#    topic_0          0
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:534: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:534: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
#  >>> Extracted 9 chunks from image
#  Too few sentences — skipping
#  >>> Extracted 18 chunks from image
# topic_0: ['network', 'pdf', 'traffic', 'internet', 'data']
# topic_1: ['anomaly', 'developersof', 'encryption', 'user', 'pdf']
# topic_2: ['protocols', 'asa', 'traditional', 'fgta', 'layers']
# Extracted 18 chunks from image
#
#  Confusion Matrix:
#               topic_0     topic_1     topic_2
#    topic_0          2           0           0
#    topic_1          0           1           1
#    topic_2          1           0           1
#  >>> Extracted 28 chunks from image
# topic_0: ['solution', 'improve', 'lookat', 'fig', 'project']
# topic_1: ['mlops', 'section', 'literature', 'main', 'taxonomy']
# topic_2: ['continuous', 'model', 'dev', 'integration', 'project']
# Extracted 28 chunks from image
#
#  Confusion Matrix:
#               topic_0     topic_1     topic_2
#    topic_0          1           3           0
#    topic_1          0           2           0
#    topic_2          0           3           0
#  >>> Extracted 18 chunks from image
# topic_0: ['text', 'sent', 'splitter', 'sentence', 'cleansing']
# topic_1: ['sentence', 'text', 'splitter', 'tokenizer', 'somethingas']
# topic_2: ['data', 'interestedin', 'specific', 'source', 'task']
# Extracted 18 chunks from image
#
#  Confusion Matrix:
#               topic_0     topic_1     topic_2
#    topic_0          3           0           0
#    topic_1          1           0           1
#    topic_2          0           0           1

# %% [markdown]
# # Vision

# %% [markdown]
# ## Image Processing and Feature detection

# %% [markdown]
# ## 2.1 Image color processing

# %%
test_img = "samples/cv/arch_m.jpg"

img_process(test_img)
# Out:
#  Grayscale using OpenCV
#
# image resolution:  (760, 1140)
# confirms conversion to NumPy array <class 'numpy.ndarray'>
#  BGR - three color chanel using OpenCV
#
# to confirm three color chanel:  (760, 1140, 3)
#  COLOR CHANELLS (R + G + B)

# %% [markdown]
# ### Image conversion

# %%
# conversion

rgbtobgr1(test_img)

rgbtobgr2(test_img)
# Out:
#  Method 1: Using cv2.cvtColor
#  Method 2: NumPy array slicing

# %% [markdown]
# ### Resize image

# %%
# resize image

imgshrink(test_img)

imgexpand(test_img)

# %% [markdown]
# ### Image rotation

# %%
imgrotate(test_img, 30,2)
# Out:
# array([[[ 6,  6,  6],
#         [ 6,  6,  6],
#         [ 6,  6,  6],
#         ...,
#         [27, 21, 22],
#         [33, 28, 27],
#         [39, 34, 34]],
#
#        [[ 6,  6,  6],
#         [ 6,  6,  6],
#         [ 6,  6,  6],
#         ...,
#         [35, 29, 29],
#         [40, 35, 35],
#         [42, 39, 37]],
#
#        [[ 6,  6,  6],
#         [ 6,  6,  6],
#         [ 6,  6,  6],
#         ...,
#         [42, 37, 36],
#         [41, 36, 35],
#         [40, 37, 34]],
#
#        ...,
#
#        [[ 5,  5,  5],
#         [ 5,  5,  5],
#         [ 5,  5,  5],
#         ...,
#         [63, 59, 56],
#         [63, 59, 56],
#         [63, 59, 56]],
#
#        [[ 5,  5,  5],
#         [ 4,  4,  4],
#         [ 4,  4,  4],
#         ...,
#         [63, 59, 56],
#         [62, 58, 55],
#         [62, 58, 55]],
#
#        [[ 4,  4,  4],
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         ...,
#         [62, 58, 55],
#         [62, 58, 55],
#         [62, 58, 55]]], shape=(760, 1140, 3), dtype=uint8)

# %% [markdown]
# ### Image Thresholding

# %%
imagethresholding(test_img)

# %% [markdown]
# ### Image Blurring

# %%
imgblur(test_img)

imgblur(test_img, method='standard', blurkrl=(9,9))

# %% [markdown]
# ### Image blending with text
#
# Example how to overlay text on the rotated image

# %%
imgr = imgrotate(test_img, 30,2, display=False)
txt = 'Arch is the way...'
imgaddtext(imgr, txt, org=(200,700), color=(255,255,255))

# %% [markdown]
# ## 2.2 Image Feature Detection

# %% [markdown]
# ### Detect/draw contours on an image

# %%
cat_img = "samples/cv/IMG_7744.jpeg"

# default mode RETR_THREE retrieves all contours including nested ones
imgcontours(cat_img, tx=190, br=4)
# only retrieves the outermost contours
imgcontours(cat_img, mode=cv2.RETR_EXTERNAL, tx=190, br=4)
# Out:
#  Number of contours detected: 1460
#  Number of contours detected: 719

# %% [markdown]
# ### Sobel
# Edge detection

# %%
imgedges(cat_img, x=29, y=21)

# %% [markdown]
# ### Canny
#
# Detecting edges/boundries for text blox images back grounds

# %%
page_img = "samples/cv/Screenshot.png"

imgcanny(page_img, blur_krl=(1,1))
# Out:
#  Median value: 255.0

# %% [markdown]
# ## 2.3 Watershed
#
# isolates foreground objects from the background
#
# using my own functions predifined (all based on lab examples)

# %%
imgwatershed(page_img)
# Out:
#  Segments detected: 3

# %% [markdown]
# ##  2.4 Image enhancment pipline example
#
# Image sharpening and show histogram (based on something i used in the photohop in the past)

# %%
page_img = "samples/cv/IMG_7994.jpg"

dffiles = load_files("samples/cv/", extensions=['.png', '.jpg'])
print(dffiles)

for d in dffiles:
    imgenhancment(d)
# Out:
# Found 11 files in 'samples/cv/'
# ['samples/cv/4.jpg', 'samples/cv/IMG_7993.jpg', 'samples/cv/IMG_7994.jpg', 'samples/cv/Screenshot.png', 'samples/cv/Test2.png', 'samples/cv/arch_m.jpg', 'samples/cv/pdf0.png', 'samples/cv/pdf1.png', 'samples/cv/pdf2.png', 'samples/cv/pdf3.png', 'samples/cv/pdf4.png']

# %% [markdown]
# # Multi-modal

# %% [markdown]
# ## Multi-modal Integration and Insights

# %%
# code here

# %% [markdown]
# # Final Output

# %%
# code
