# %% [markdown]
#  *Artificial Intelligence for Vision & NLP* &nbsp; | &nbsp;  *ATU Donegal - Postgrad Diploma in Big Data Analytics & Artificial Intelligence*
#
# # Student Submisison
# Name           : Sebastian Szmytka                <br>
# Student Number : L 00196514        <br>
# Due Date       : 12th May 2359hrs                <br>
# Assignment     : CA2             <br>
# Module         : AI for Vision and NLP    <br>
# Course         : Postgraduate Diploma in Big Data Analytics and AI

# %% [markdown]
# ## NLP and Vision Pipeline : High Level
# An image of your working pipeline at high level can be inserted here

# %% [markdown]
# # Initialisation
# Perform pip installs(or use a requirements.txt) <br>
# perform imports

# %% [markdown]
# ## Install packages

# %%
# pip installs

# %% [markdown]
# ## Imports

# %%
# imports
import os
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
import cv2
import pytesseract
from pytesseract import Output
import pymupdf
import sys
import re
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3

# %% [markdown]
# # Support Functions

# %%
# test
print("cv2", cv2.__version__)
print("pytesseract", pytesseract.__version__)
# Out:
# cv2 4.13.0
# pytesseract 0.3.13

# %%
# code here
def create_lemmatization(text_to_convert):
    for token in text_to_convert:
        print (f"{token.text:{15}} {token.lemma_:{30}}")

def create_tokenize(text_token):
    tokens = nltk.word_tokenize(text_token)

def check_fileformat(filepath):
    """
    function to validate file format example if its an image or a pdf file
    1. checks if file exists
    2. identify the extention
    3. make decision based on the file format
    """

    if not os.path.isfile(filepath):
        return f"Error: file not found: {filepath}"

    fileextension = os.path.splitext(filepath)[1].lower()

    print(fileextension)

    try:
        if fileextension == '.pdf':
            print("file type: ", fileextension)
            return pdf_tostring(filepath)
        elif fileextension in [".bmp",".jpg",".png",".tiff",".jpeg"]:
            print("file type: ", fileextension)
            return image_tostring(filepath)
        else:
            print("Unsupported format: ", fileextension)

    except Exception as e:
        return f"An error occurred: {e}"

def image_tostring(img):
    """
    image to string function
    """
    # Adding custom options for tesseract
    # using the latest tesseract verion 5.0, these values are better work well
    # Troubleshooting - prints below
    print(f"\n image_tostring received: '{img}'")  # ← add this
    print(f"\n repr: {repr(img)}")                 # ← and this

    img = cv2.imread(img)
    if img is None:
        return f"Error: could not read image at {img}"
    print(img.shape)
    custom_config = r'--oem 1 --psm 6' 
    #Convert image to String
    st = pytesseract.image_to_string(img, config=custom_config)
    # print output
    print(st)
    return st

def pdf_tostring(pdf):
    """
    pdf to string function
    """
    doc = pymupdf.open(pdf)
    st = ""
    output_folder = "samples/png_outputs/"
    os.makedirs(output_folder, exist_ok=True)
    # if the pdf ad multiple pages this for loop can be edited to accommodate
    for page in doc:
        # setting the dpi to 200 for higher quality image - this can be set higher
        img = page.get_pixmap(dpi=200)
        #Saving the image to local drive where it can be accessed again
        path = os.path.join(output_folder, f"pdf{page.number}.png")
        print("\n Saving to path: ", path)
        print("\n Path type: ", type(path))
        img.save(path)

        print("\n File exists after save: " ,os.path.isfile(path))
        
        txt = image_tostring(path)
        
        #adding txt to one final string
        st += txt
    return st

# %% [markdown]
# # NLP

# %% [markdown]
# ## Text Extraction end Processing

# %%
## code
# test of file format function

cwd = os.getcwd()
print(f"\n Current Directory: {cwd}")
file1 = "KaggleDataset/images/0.jpg"
file2 = "samples/pdf/sample1.pdf"
st = check_fileformat(file2)
# Out:
#  Current Directory: /Users/sebszmytka/GIT_NLP/ca2-assignment-lightarchivist-1
# .pdf
# file type:  .pdf
#
#  Saving to path:  samples/png_outputs/pdf0.png
#
#  Path type:  <class 'str'>
#
#  File exists after save:  True
#
#  image_tostring received: 'samples/png_outputs/pdf0.png'
#
#  repr: 'samples/png_outputs/pdf0.png'
# (2339, 1654, 3)
# Applying the MLOps Methodology to
# your ML project.
# Using the MLOps taxonomy and methodology presented in the papers, choose one realistic
# machine learning project you have been working on.
# You must base your discussion on a system that you have personally implemented, designed,
# or are currently developing in your academic programme/work life.
# Briefly state the module or project and the type of dataset/ml algorithm you used.
# Padlet Post (80%)
# Your task is to explain how this system would be operationalised using the MLOps lifecycle.
# You must select at least 6 stages from the methodology and, for each stage:
# 1. Briefly describe what would happen in that stage for your system
#
# You may choose from the following stages:
#
# 1. Business Problem Understanding
#
# 2. Data Acquisition & Management
#
# 3. ML Training and Testing
#
# 4. Model Deployment
#
# 5. Continuous Integration
#
# 6. Continuous Delivery
#
# 7. Continuous Training
#
# 8. Continuous Monitoring
#
# 9. Explainability
#
# 10. Sustainability
#
# 2. For each stage included, describe one real problem you encountered (or realistically
# expect to encounter) when implementing this stage.

# %% [markdown]
# TOKENISATION

# %%
# tokenisation - load english language library

nlp = spacy.load("en_core_web_sm")

# %%
# process and show tokens
nlp_sentence = nlp(st)

for token in nlp_sentence:
    print (token.text, token.pos_, end = " | ") # sentence use and separation

# counting tokens
print("\n\n Number of tokens: ", len(nlp_sentence))
# Out:
# Applying VERB | the DET | MLOps PROPN | Methodology PROPN | to ADP |
#  SPACE | your PRON | ML PROPN | project NOUN | . PUNCT |
#  SPACE | Using VERB | the DET | MLOps PROPN | taxonomy NOUN | and CCONJ | methodology NOUN | presented VERB | in ADP | the DET | papers NOUN | , PUNCT | choose VERB | one NUM | realistic ADJ |
#  SPACE | machine NOUN | learning NOUN | project NOUN | you PRON | have AUX | been AUX | working VERB | on ADP | . PUNCT |
#  SPACE | You PRON | must AUX | base VERB | your PRON | discussion NOUN | on ADP | a DET | system NOUN | that PRON | you PRON | have AUX | personally ADV | implemented VERB | , PUNCT | designed VERB | , PUNCT |
#  SPACE | or CCONJ | are AUX | currently ADV | developing VERB | in ADP | your PRON | academic ADJ | programme NOUN | / SYM | work NOUN | life NOUN | . PUNCT |
#  SPACE | Briefly ADV | state VERB | the DET | module NOUN | or CCONJ | project NOUN | and CCONJ | the DET | type NOUN | of ADP | dataset NOUN | / PUNCT | ml PROPN | algorithm PROPN | you PRON | used VERB | . PUNCT |
#  SPACE | Padlet PROPN | Post PROPN | ( PUNCT | 80 NUM | % NOUN | ) PUNCT |
#  SPACE | Your PRON | task NOUN | is AUX | to PART | explain VERB | how SCONJ | this DET | system NOUN | would AUX | be AUX | operationalised VERB | using VERB | the DET | MLOps PROPN | lifecycle NOUN | . PUNCT |
#  SPACE | You PRON | must AUX | select VERB | at ADV | least ADV | 6 NUM | stages NOUN | from ADP | the DET | methodology NOUN | and CCONJ | , PUNCT | for ADP | each DET | stage NOUN | : PUNCT |
#  SPACE | 1 X | . PUNCT | Briefly ADV | describe VERB | what PRON | would AUX | happen VERB | in ADP | that DET | stage NOUN | for ADP | your PRON | system NOUN |
#
#  SPACE | You PRON | may AUX | choose VERB | from ADP | the DET | following VERB | stages NOUN | : PUNCT |
#
#  SPACE | 1 X | . PUNCT | Business PROPN | Problem PROPN | Understanding PROPN |
#
#  SPACE | 2 NUM | . PUNCT | Data PROPN | Acquisition PROPN | & CCONJ | Management PROPN |
#
#  SPACE | 3 NUM | . PUNCT | ML PROPN | Training PROPN | and CCONJ | Testing PROPN |
#
#  SPACE | 4 NUM | . PUNCT | Model PROPN | Deployment PROPN |
#
#  SPACE | 5 NUM | . PUNCT | Continuous PROPN | Integration PROPN |
#
#  SPACE | 6 NUM | . PUNCT | Continuous PROPN | Delivery PROPN |
#
#  SPACE | 7 NUM | . PUNCT | Continuous PROPN | Training PROPN |
#
#  SPACE | 8 NUM | . PUNCT | Continuous PROPN | Monitoring PROPN |
#
#  SPACE | 9 NUM | . PUNCT | Explainability NOUN |
#
#  SPACE | 10 NUM | . PUNCT | Sustainability NOUN |
#
#  SPACE | 2 NUM | . PUNCT | For ADP | each DET | stage NOUN | included VERB | , PUNCT | describe VERB | one NUM | real ADJ | problem NOUN | you PRON | encountered VERB | ( PUNCT | or CCONJ | realistically ADV |
#  SPACE | expect VERB | to PART | encounter VERB | ) PUNCT | when SCONJ | implementing VERB | this DET | stage NOUN | . PUNCT |
#  SPACE |
#
#  Number of tokens:  228

# %% [markdown]
# ### STEMMING
#
# Initially i was going to remove the numbers in text but then I realized that they are required for context

# %%
porter_stemmer = PorterStemmer()
st_port = st.split() # conver to list of words

for word in st_port:
    print(word + " ------> " + porter_stemmer.stem(word))
# Out:
# Applying ------> appli
# the ------> the
# MLOps ------> mlop
# Methodology ------> methodolog
# to ------> to
# your ------> your
# ML ------> ml
# project. ------> project.
# Using ------> use
# the ------> the
# MLOps ------> mlop
# taxonomy ------> taxonomi
# and ------> and
# methodology ------> methodolog
# presented ------> present
# in ------> in
# the ------> the
# papers, ------> papers,
# choose ------> choos
# one ------> one
# realistic ------> realist
# machine ------> machin
# learning ------> learn
# project ------> project
# you ------> you
# have ------> have
# been ------> been
# working ------> work
# on. ------> on.
# You ------> you
# must ------> must
# base ------> base
# your ------> your
# discussion ------> discuss
# on ------> on
# a ------> a
# system ------> system
# that ------> that
# you ------> you
# have ------> have
# personally ------> person
# implemented, ------> implemented,
# designed, ------> designed,
# or ------> or
# are ------> are
# currently ------> current
# developing ------> develop
# in ------> in
# your ------> your
# academic ------> academ
# programme/work ------> programme/work
# life. ------> life.
# Briefly ------> briefli
# state ------> state
# the ------> the
# module ------> modul
# or ------> or
# project ------> project
# and ------> and
# the ------> the
# type ------> type
# of ------> of
# dataset/ml ------> dataset/ml
# algorithm ------> algorithm
# you ------> you
# used. ------> used.
# Padlet ------> padlet
# Post ------> post
# (80%) ------> (80%)
# Your ------> your
# task ------> task
# is ------> is
# to ------> to
# explain ------> explain
# how ------> how
# this ------> thi
# system ------> system
# would ------> would
# be ------> be
# operationalised ------> operationalis
# using ------> use
# the ------> the
# MLOps ------> mlop
# lifecycle. ------> lifecycle.
# You ------> you
# must ------> must
# select ------> select
# at ------> at
# least ------> least
# 6 ------> 6
# stages ------> stage
# from ------> from
# the ------> the
# methodology ------> methodolog
# and, ------> and,
# for ------> for
# each ------> each
# stage: ------> stage:
# 1. ------> 1.
# Briefly ------> briefli
# describe ------> describ
# what ------> what
# would ------> would
# happen ------> happen
# in ------> in
# that ------> that
# stage ------> stage
# for ------> for
# your ------> your
# system ------> system
# You ------> you
# may ------> may
# choose ------> choos
# from ------> from
# the ------> the
# following ------> follow
# stages: ------> stages:
# 1. ------> 1.
# Business ------> busi
# Problem ------> problem
# Understanding ------> understand
# 2. ------> 2.
# Data ------> data
# Acquisition ------> acquisit
# & ------> &
# Management ------> manag
# 3. ------> 3.
# ML ------> ml
# Training ------> train
# and ------> and
# Testing ------> test
# 4. ------> 4.
# Model ------> model
# Deployment ------> deploy
# 5. ------> 5.
# Continuous ------> continu
# Integration ------> integr
# 6. ------> 6.
# Continuous ------> continu
# Delivery ------> deliveri
# 7. ------> 7.
# Continuous ------> continu
# Training ------> train
# 8. ------> 8.
# Continuous ------> continu
# Monitoring ------> monitor
# 9. ------> 9.
# Explainability ------> explain
# 10. ------> 10.
# Sustainability ------> sustain
# 2. ------> 2.
# For ------> for
# each ------> each
# stage ------> stage
# included, ------> included,
# describe ------> describ
# one ------> one
# real ------> real
# problem ------> problem
# you ------> you
# encountered ------> encount
# (or ------> (or
# realistically ------> realist
# expect ------> expect
# to ------> to
# encounter) ------> encounter)
# when ------> when
# implementing ------> implement
# this ------> thi
# stage. ------> stage.

# %% [markdown]
# LEMMATISATION

# %% [markdown]
# STOPWORD

# %% [markdown]
# # Vision

# %% [markdown]
# ## Image Processing and Feature detection

# %%
# code here...

# %% [markdown]
# # Multi-modal

# %% [markdown]
# ## Multi-modal Integration and Insights

# %%
# code here

# %% [markdown]
# # Final Output

# %%
# code
