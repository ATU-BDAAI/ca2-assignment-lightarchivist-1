# %% [markdown]
#  *Artificial Intelligence for Vision & NLP* &nbsp; | &nbsp;  *ATU Donegal - Postgrad Diploma in Big Data Analytics & Artificial Intelligence*
#
# # Student Submisison
# Name           : Sebastian Szmytka                <br>
# Student Number : L 00196514        <br>
# Due Date       : 12th May 2359hrs                <br>
# Assignment     : CA2             <br>
# Module         : AI for Vision and NLP    <br>
# Course         : Postgraduate Diploma in Big Data Analytics and AI

# %% [markdown]
# ## NLP and Vision Pipeline : High Level
# An image of your working pipeline at high level can be inserted here

# %% [markdown]
# # Initialisation
# Perform pip installs(or use a requirements.txt) <br>
# perform imports

# %% [markdown]
# ## Install packages

# %%
# pip installs

# %% [markdown]
# ## Imports

# %%
# imports basics + text and analysis
import os
import spacy
from spacy import displacy
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
import cv2
import pytesseract
from pytesseract import Output
import pymupdf
import sys
import re
print(sys.executable)

# imports for CV
from matplotlib import pyplot as plt
import cv2
import numpy as np
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3

# %%
# test
print("cv2", cv2.__version__)
print("pytesseract", pytesseract.__version__)
# Out:
# cv2 4.13.0
# pytesseract 0.3.13

# %% [markdown]
# # Support Functions

# %%
# Support functions
def create_lemmatization(text_to_convert):
    text_to_convert = nlp(text_to_convert)
    for token in text_to_convert:
        print (f"{token.text:{15}} {token.lemma_:{30}}")

def create_tokenize(text_token):
    nlp = spacy.load("en_core_web_sm")
    text_token = nlp(text_token)
    for token in text_token:
        print (token.text, token.pos_, end = " | ")

    print("\n\n Number of tokens: ", len(nlp_sentence))

def check_fileformat(filepath):
    """
    function to validate file format example if its an image or a pdf file
    1. checks if file exists
    2. identify the extention
    3. make decision based on the file format and process it
    """

    if not os.path.isfile(filepath):
        return f"Error: file not found: {filepath}"

    fileextension = os.path.splitext(filepath)[1].lower()

    print(fileextension)

    try:
        if fileextension == '.pdf':
            print("file type: ", fileextension)
            return pdf_tostring(filepath)
        elif fileextension in [".bmp",".jpg",".png",".tiff",".jpeg"]:
            print("file type: ", fileextension)
            return image_tostring(filepath)
        else:
            print("Unsupported format: ", fileextension)

    except Exception as e:
        return f"An error occurred: {e}"

def image_tostring(img):
    """
    image to string function + image to boxes
    """
    # Adding custom options for tesseract
    # using the latest tesseract verion 5.0, these values are better work well
    # Troubleshooting - prints below

    print(f"\n image_tostring received: '{img}'")  
    print(f"\n repr: {repr(img)}")                 

    img = cv2.imread(img)
    if img is None:
        return f"Error: could not read image at {img}"

    else:
        
        h, w, c = img.shape

        boxes = pytesseract.image_to_boxes(img)
        
        for i in boxes.splitlines():
            i = i.split(' ')
            img = cv2.rectangle(img, (int(i[1]), h - int(i[2])), (int(i[3]), h - int(i[4])), (0, 255, 0), 2) 
            
    plt.imshow(img)
    plt.axis("off")
    plt.show()
    
    print(img.shape)

    custom_config = r'--oem 1 --psm 6' 
    #Convert image to String
    #st = pytesseract.image_to_string(img, config=custom_config)
    # print output
    print(st)
    return st

def pdf_tostring(pdf):
    """
    pdf to string function convers pdf to png file
    """
    doc = pymupdf.open(pdf)
    st = ""
    output_folder = "samples/png_outputs/"
    os.makedirs(output_folder, exist_ok=True)
    # if the pdf has multiple pages this for loop can be edited to accommodate
    for page in doc:
        # setting the dpi to 200 for higher quality image - this can be set higher
        img = page.get_pixmap(dpi=300)
        #Saving the image to local drive where it can be accessed again
        path = os.path.join(output_folder, f"pdf{page.number}.png")
        print("\n Saving to path: ", path)
        print("\n Path type: ", type(path))
        img.save(path)

        print("\n File exists after save: " ,os.path.isfile(path))
        
        txt = image_tostring(path)
        
        #adding txt to one final string
        st += txt
    return st

def ImgKeyFeatures(sampleimg):
     
     """
     Function to suport section 3 of the CA2 NLP - Detectand recognize key featuresin both the text and images:
     - tables
     - signatures
     - diagrams
     - figures     
     """

     print(sampleimg)

# %% [markdown]
# # NLP

# %% [markdown]
# ## Text Extraction end Processing (OCR)

# %%
## code
# test of file format function

cwd = os.getcwd()
print(f"\n Current Directory: {cwd}\n")
file1 = "KaggleDataset/images/0.jpg \n"
file2 = "samples/pdf/TextCleansing-2.pdf \n"



st = check_fileformat(file2)
st_full = st

# just to make it tidier i will limit the amout of text to make the outputs cleaner

# st = "\n".join(st.split("\n")[:20])
# Out:
#  Current Directory: /Users/sebszmytka/GIT_NLP/ca2-assignment-lightarchivist-1

# %% [markdown]
# ### Tokenisation
# segmenting sentences in to units called "tokens"

# %%
# tokenisation - load english language library

nlp = spacy.load("en_core_web_sm")

# %%
# process and show tokens
nlp_sentence = nlp(st)

for token in nlp_sentence:
    print (token.text, token.pos_, end = " | ") # sentence use and separation

# counting tokens
print("\n\n Number of tokens: ", len(nlp_sentence))
# Out:
# Error NOUN | : PUNCT | file NOUN | not PART | found VERB | : PUNCT | samples NOUN | / SYM | pdf NOUN | / SYM | TextCleansing-2.pdf NOUN |
#  SPACE |
#
#  Number of tokens:  12

# %%
# using function defined in support functions section

create_tokenize(st)
# Out:
# Error NOUN | : PUNCT | file NOUN | not PART | found VERB | : PUNCT | samples NOUN | / SYM | pdf NOUN | / SYM | TextCleansing-2.pdf NOUN |
#  SPACE |
#
#  Number of tokens:  12

# %% [markdown]
# ### Stemming
# extracting the root of the word

# %%
porter_stemmer = PorterStemmer()
st_port = st.split() # conver to list of words

for word in st_port:
    print(word + " ------> " + porter_stemmer.stem(word))
# Out:
# Error: ------> error:
# file ------> file
# not ------> not
# found: ------> found:
# samples/pdf/TextCleansing-2.pdf ------> samples/pdf/textcleansing-2.pdf

# %% [markdown]
# ### Lemmatisation
# compares to stemming, this is method uses gramar/actual dictionary form

# %%
# creating document object

document = nlp(st)

# check for tokens and associated parts-of-speech (POS) tags

for t in document:
    print(t, t.pos_)
# Out:
# Error NOUN
# : PUNCT
# file NOUN
# not PART
# found VERB
# : PUNCT
# samples NOUN
# / SYM
# pdf NOUN
# / SYM
# TextCleansing-2.pdf NOUN
#
#  SPACE

# %%
# root words analysis

for w in document:
    print(w.text + " |---> " + w.lemma_)
# Out:
# Error |---> error
# : |---> :
# file |---> file
# not |---> not
# found |---> find
# : |---> :
# samples |---> sample
# / |---> /
# pdf |---> pdf
# / |---> /
# TextCleansing-2.pdf |---> textcleansing-2.pdf
#
#  |--->

# %%
# Lemmatisation versus stemming

for w in document:
    print(w.text + " |---> " + w.lemma_,"\t", w.pos_)
# Out:
# Error |---> error 	 NOUN
# : |---> : 	 PUNCT
# file |---> file 	 NOUN
# not |---> not 	 PART
# found |---> find 	 VERB
# : |---> : 	 PUNCT
# samples |---> sample 	 NOUN
# / |---> / 	 SYM
# pdf |---> pdf 	 NOUN
# / |---> / 	 SYM
# TextCleansing-2.pdf |---> textcleansing-2.pdf 	 NOUN
#
#  |--->
#  	 SPACE

# %%
# using function created 

create_lemmatization(st)
# Out:
# Error           error
# :               :
# file            file
# not             not
# found           find
# :               :
# samples         sample
# /               /
# pdf             pdf
# /               /
# TextCleansing-2.pdf textcleansing-2.pdf

# %%
# View token tags

for t in document:
    print(f"{t.text:{20}} {t.pos_:{15}}  {t.tag_:{10}} {spacy.explain(t.tag_)}")
# Out:
# Error                NOUN             NN         noun, singular or mass
# :                    PUNCT            :          punctuation mark, colon or ellipsis
# file                 NOUN             NN         noun, singular or mass
# not                  PART             RB         adverb
# found                VERB             VBN        verb, past participle
# :                    PUNCT            :          punctuation mark, colon or ellipsis
# samples              NOUN             NNS        noun, plural
# /                    SYM              SYM        symbol
# pdf                  NOUN             NN         noun, singular or mass
# /                    SYM              SYM        symbol
# TextCleansing-2.pdf  NOUN             NN         noun, singular or mass
#
#                     SPACE            _SP        whitespace

# %%
# POS Tags 

print("\n >>> spaCy predicting the use of tokens in the sentence and can also find is verb is present or past tense \n")

for t in document:
    print(f" {t.text:{10}} {t.pos_:{10}} {t.tag_:{10}} {spacy.explain(t.tag_):{20}}")

print("\n >>> filtered option for one word \n")

print(f"{document[6].text:{10}} {document[6].pos_:{10}} {document[6].tag_:{10}} {spacy.explain(document[6].tag_):{20}}")

print("\n >>> POS Tag Frequency\n")
fcount = document.count_by(spacy.attrs.POS)
print("\n", fcount, "\n") 

print("\nLooking up ID of the POS tag 100: \n")
document.vocab[100].text

print("\n >>> POS Count Frequency is an disctionary, so checking in:  \n")

for i, fr in fcount.items():
    print(f" {i:{10}} {document.vocab[i].text:{10}} {fr}")

print("\n >>> For more details output we can use spacy.attrs.TAG: \n")

finegrainedPOS = document.count_by(spacy.attrs.TAG)

for i, fr in sorted (finegrainedPOS.items()):
    print(f" {i:{20}} {document.vocab[i].text:{10}} {fr}")

print("\n >>> Visualization of POS tags using displacy module: \n")

displacy.render(document, style='dep', jupyter=True, options={'distance': 120})
# Out:
#  >>> spaCy predicting the use of tokens in the sentence and can also find is verb is present or past tense
#
#  Error      NOUN       NN         noun, singular or mass
#  :          PUNCT      :          punctuation mark, colon or ellipsis
#  file       NOUN       NN         noun, singular or mass
#  not        PART       RB         adverb
#  found      VERB       VBN        verb, past participle
#  :          PUNCT      :          punctuation mark, colon or ellipsis
#  samples    NOUN       NNS        noun, plural
#  /          SYM        SYM        symbol
#  pdf        NOUN       NN         noun, singular or mass
#  /          SYM        SYM        symbol
#  TextCleansing-2.pdf NOUN       NN         noun, singular or mass
#
#           SPACE      _SP        whitespace
#
#  >>> filtered option for one word
#
# samples    NOUN       NNS        noun, plural
#
#  >>> POS Tag Frequency
#
#
#  {92: 5, 97: 2, 94: 1, 100: 1, 99: 2, 103: 1}
#
#
# Looking up ID of the POS tag 100:
#
#
#  >>> POS Count Frequency is an disctionary, so checking in:
#
#          92 NOUN       5
#          97 PUNCT      2
#          94 PART       1
#         100 VERB       1
#          99 SYM        2
#         103 SPACE      1
#
#  >>> For more details output we can use spacy.attrs.TAG:
#
#                    99 SYM        2
#    164681854541413346 RB         1
#    783433942507015291 NNS        1
#   3822385049556375858 VBN        1
#   6893682062797376370 _SP        1
#  11532473245541075862 :          2
#  15308085513773655218 NN         4
#
#  >>> Visualization of POS tags using displacy module:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="917b8508609f4ea49b5fe394aabe586d-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Error:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">file</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">found:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">samples/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">pdf/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">TextCleansing-2.pdf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 410.0,2.0 410.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-1" stroke-width="2px" d="M190,182.0 C190,62.0 405.0,62.0 405.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">neg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-3" stroke-width="2px" d="M430,182.0 C430,122.0 520.0,122.0 520.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520.0,184.0 L528.0,172.0 512.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-4" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-5" stroke-width="2px" d="M550,182.0 C550,62.0 765.0,62.0 765.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,184.0 L773.0,172.0 757.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-917b8508609f4ea49b5fe394aabe586d-0-6" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-917b8508609f4ea49b5fe394aabe586d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,184.0 L888.0,172.0 872.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Stopword
# removing common words with no meaning

# %%
# loading whats reqired
nltk.download('punkt_tab')

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/sebszmytka/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebszmytka/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# using NLTK

print("\n >>> stop words with NLTK \n")

st_tokens = word_tokenize(st)

tokens_without_sw = [word for word in st_tokens if not word in stopwords.words()]

print(tokens_without_sw)

print("\n",len(tokens_without_sw))

# using spaCy

sp = spacy.load("en_core_web_sm")

sp_stopwords = sp.Defaults.stop_words

print("\n >>> stop words with spaCy for comparasment \n")

spacy_st = word_tokenize(st)

tokens_without_sw_sp =[ word for word in spacy_st if not word in sp_stopwords]

print("\n", tokens_without_sw_sp, "\n")

print("\n",len(tokens_without_sw_sp))
# Out:
#  >>> stop words with NLTK
#
# ['Error', ':', 'file', 'found', ':', 'samples/pdf/TextCleansing-2.pdf']
#
#  6
#
#  >>> stop words with spaCy for comparasment
#
#
#  ['Error', ':', 'file', 'found', ':', 'samples/pdf/TextCleansing-2.pdf']
#
#
#  6

# %%
# larger text for comparasment

fulltxt = word_tokenize(st_full)
 
# NLTK
tokens_full = [word for word in fulltxt if not word in stopwords.words()]

print("\n",len(tokens_full))

# scaCy

tokens_full_sp =[ word for word in fulltxt if not word in sp_stopwords]


print("\n",len(tokens_full_sp))
# Out:
#  6
#
#  6

# %%
# Joining tokens
jtokens = (" ").join(tokens_without_sw)
print(jtokens)
# Out:
# Error : file found : samples/pdf/TextCleansing-2.pdf

# %%
# adding stop words to the list

print("\n >> Elenents in stopword list: ",len(stopwords.words('english')), "\n") # how long is the list
print(stopwords.words('english')) # just to see whats in the list

new_stopwords = stopwords.words('english')
new_stopwords.append('NLP')

new_stopwords.append('>')

print("\n >>> New stopwords list\n")

print("Elements in new stopword list: ",len(new_stopwords), "\n")

print(new_stopwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # adding stop words to the list
# ----> 3 print("\n >> Elenents in stopword list: ",len(stopwords.words('english')), "\n") # how long is the list
#       4 print(stopwords.words('english')) # just to see whats in the list
#       6 new_stopwords = stopwords.words('english')
#
# NameError: name 'stopwords' is not defined

# %% [markdown]
# ### Named Entity Recognition (NER)
# predicting "real world objects" with spaCy

# %%
# iterating over entities found in hte document
for ent in document.ents:
    print(f"{ent.text:{30}} {ent.label_:{15}} {spacy.explain(ent.label_)}")

# Visualising NER using displacy
displacy.render(document, style='ent', jupyter=True)
# Out:
# Deh Worf                       PERSON          People, including fictional
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deh Worf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ling arid Heong)<br><br>Text cleansing<br><br>Othce we have jpansed) the text fridin a waitiety, off data soumoes) the chiallerige ils fo<br><br>nike sense Of thils naw dattal. Neékt cleansing iis loosely; used fion nfiost of the clleaniing,<br><br>to be done on fext, depending) on the daital source, pansiing perfonmmamioe) exitenrial<br></div></span>

# %% [markdown]
# ### Noun Chunks
# extracting meaningful noun phrases

# %%
for chunk in document.noun_chunks:
    print(chunk.text)
# Out:
# Deh Worf ling arid Heong
# Othce
# we
# the text
# a waitiety
# data soumoes
# the chiallerige
# nike sense
# naw dattal
# fion nfiost
# the clleaniing
# fext
# the daital source
# perfonmmamioe) exitenrial

# %% [markdown]
# ### Prefix / Suffix
# morphological analysis

# %%
for t in document:
    print(f"{t.text:{20}} prefix: {t.prefix_:{10}} suffix: {t.suffix_}")
# Out:
# Text                 prefix: T          suffix: ext
# Wrangling            prefix: W          suffix: ing
# and                  prefix: a          suffix: and
# Cleansin             prefix: C          suffix: sin
# ,                    prefix: ,          suffix: ,
#
#
#                    prefix:
#           suffix:
#
#
# Text                 prefix: T          suffix: ext
# cleansing            prefix: c          suffix: ing
#
#
#                    prefix:
#           suffix:
#
#
# Once                 prefix: O          suffix: nce
# we                   prefix: w          suffix: we
# have                 prefix: h          suffix: ave
# parsed               prefix: p          suffix: sed
# the                  prefix: t          suffix: the
# text                 prefix: t          suffix: ext
# from                 prefix: f          suffix: rom
# a                    prefix: a          suffix: a
# variety              prefix: v          suffix: ety
# of                   prefix: o          suffix: of
# data                 prefix: d          suffix: ata
# sources              prefix: s          suffix: ces
# ,                    prefix: ,          suffix: ,
# the                  prefix: t          suffix: the
# challenge            prefix: c          suffix: nge
# is                   prefix: i          suffix: is
# to                   prefix: t          suffix: to
#
#
#                    prefix:
#           suffix:
#
#
# make                 prefix: m          suffix: ake
# sense                prefix: s          suffix: nse
# of                   prefix: o          suffix: of
# this                 prefix: t          suffix: his
# raw                  prefix: r          suffix: raw
# data                 prefix: d          suffix: ata
# .                    prefix: .          suffix: .
# Text                 prefix: T          suffix: ext
# cleansing            prefix: c          suffix: ing
# is                   prefix: i          suffix: is
# loosely              prefix: l          suffix: ely
# used                 prefix: u          suffix: sed
# for                  prefix: f          suffix: for
# most                 prefix: m          suffix: ost
# of                   prefix: o          suffix: of
# the                  prefix: t          suffix: the
# cleaning             prefix: c          suffix: ing
#
#
#                    prefix:
#           suffix:
#
#
# to                   prefix: t          suffix: to
# be                   prefix: b          suffix: be
# done                 prefix: d          suffix: one
# on                   prefix: o          suffix: on
# text                 prefix: t          suffix: ext
# ,                    prefix: ,          suffix: ,
# depending            prefix: d          suffix: ing
# on                   prefix: o          suffix: on
# the                  prefix: t          suffix: the
# data                 prefix: d          suffix: ata
# source               prefix: s          suffix: rce
# ,                    prefix: ,          suffix: ,
# parsing              prefix: p          suffix: ing
# performance          prefix: p          suffix: nce
# ,                    prefix: ,          suffix: ,
# external             prefix: e          suffix: nal
#
#                     prefix:
#           suffix:

# %% [markdown]
# ## NLP Section Summary
#
# The following NLP techniques were applied to the extracted text:
#
# - **OCR Extraction**: Text was extracted from a PDF document using Tesseract OCR via PyMuPDF page rendering
# - **Tokenisation**: Text was broken into individual tokens with POS tags identified using spaCy
# - **Stemming**: Porter Stemmer was applied to reduce words to their root form
# - **Lemmatisation**: spaCy was used to reduce words to their dictionary base form, preserving meaning better than stemming
# - **Stopword Removal**: Common words were filtered out using both NLTK and spaCy, with a custom stopword list also demonstrated
# - **NER**: Named entities were identified and categorised (persons, organisations, locations etc.)
# - **Noun Chunks**: Key noun phrases were extracted from the text
# - **Prefix/Suffix**: Morphological analysis was performed on individual tokens

# %% [markdown]
# # Vision

# %% [markdown]
# ## Image Processing and Feature detection

# %%
# load image

testimg =

# %%
# code here...

# %% [markdown]
# # Multi-modal

# %% [markdown]
# ## Multi-modal Integration and Insights

# %%
# code here

# %% [markdown]
# # Final Output

# %%
# code
